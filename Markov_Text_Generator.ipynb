# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyadarseenyPasayat/WE-Module3/blob/main/Markov_Text_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>(New) Try the Gemini API</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/python_quickstart.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import random
from collections import defaultdict
import re

def generate_text(filename, start_word, output_length):
    # Read text from file
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

    # Preprocess text: remove punctuation and split into words
    words = re.findall(r'\b\w+\b', text.lower())

    # Create a dictionary to store word frequencies
    word_freq = defaultdict(int)
    for i in range(len(words) - 1):
        word_freq[(words[i], words[i+1])] += 1

    # Generate text
    output = [start_word]
    current_word = start_word
    for _ in range(int(output_length) - 1):
        next_word_candidates = [word for word in words if (current_word, word) in word_freq]
        print(next_word_candidates)
        if not next_word_candidates:
            break
        next_word = random.choices(next_word_candidates, weights=[word_freq[(current_word, w)] for w in next_word_candidates])[0]
        output.append(next_word)
        current_word = next_word

    return ' '.join(output)

# Example usage:
filename = 'HISTORY.txt'
start_word = 'the'
output_length = 100
generated_text = generate_text(filename, start_word, output_length)
print(generated_text)
# Out:
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['is', 'is', 'and', 'is', 'is', 'not', 'is', 'is', 'and', 'is', 'and', 'and', 'and', 'and', 'is', 'is', 'and', 'not', 'when', 'and', 'is', 'output', 'format', 'and', 'is', 'is', 'is', 'and', 'and', 'and', 'not', 'and', 'is', 'not', 'is', 'is', 'is', 'and', 'stack', 'stack', 'not', 'format', 'and', 'and', 'is', 'and', 'when', 'and', 'and', 'and', 'output', 'is', 're', 'and', 'is', 'when', 'and', 'stack', 'stack', 'api', 'is', 'when', 'though', 'is', 'stack', 'and', 'and', 'is', 'format', 'stack', 'stack', 'when', 'and']
# ['in', 'a', 'no', 'a', 'in', 'based', 'a', 'basically', 'not', 'being', 'now', 'launching', 'a', 'now', 'in', 'a', 'currently', 'in', 'in', 'a', 'a', 'alpha', 'a', 'in', 'a', 'an', 'an', 'in', 'a', 'not', 'a', 'in', 'now', 'a', 'used', 'a', 'used', 'a', 'a', 'an', 'a', 'in', 'a', 'a', 'in', 'now', 'present', 'a', 'now', 'now', 'a', 'in', 'in', 'an', 'a', 'based', 'a', 'in', 'currently', 'a', 'a', 'not', 'in', 'a', 'not', 'opened', 'currently', 'a', 'an', 'distributed', 'covered', 'in', 'used', 'not', 'now', 'reflected', 'in', 'a', 'an', 'in', 'now', 'based', 'a', 'now', 'a', 'a', 'in', 'in', 'a', 'a', 'a', 'a', 'in', 'a', 'a', 'in', 'a', 'effectively', 'a', 'a', 'a', 'opened', 'now', 'a', 'a', 'explicitly', 'still', 'a', 'in', 'a', 'still', 'now', 'in', 'in', 'in', 'now', 'now', 'in', 'in', 'a', 'a', 'in', 'a', 'now', 'in', 'a', 'distributed']
# ['to', 'in', 'a', 'a', 'in', 'a', 'to', 'a', 'be', 'to', 'in', 'a', 'in', 'in', 'a', 'a', 'be', 'to', 'to', 'a', 'in', 'a', 'to', 'in', 'supports', 'a', 'be', 'to', 'a', 'be', 'in', 'supports', 'a', 'to', 'a', 'to', 'a', 'a', 'a', 'in', 'a', 'to', 'a', 'be', 'to', 'to', 'in', 'works', 'a', 'loads', 'a', 'to', 'in', 'to', 'in', 'a', 'a', 'in', 'works', 'a', 'a', 'in', 'be', 'to', 'to', 'to', 'a', 'to', 'to', 'a', 'in', 'recognizes', 'in', 'to', 'a', 'in', 'to', 'inserts', 'to', 'a', 'to', 'to', 'be', 'always', 'to', 'works', 'to', 'a', 'to', 'to', 'a', 'in', 'to', 'in', 'a', 'a', 'a', 'a', 'in', 'a', 'to', 'a', 'in', 'a', 'a', 'loads', 'a', 'a', 'be', 'a', 'a', 'to', 'to', 'actually', 'a', 'to', 'be', 'to', 'in', 'a', 'actually', 'works', 'in', 'to', 'in', 'in', 'write', 'to', 'in', 'in', 'to', 'a', 'to', 'a', 'in', 'a', 'show', 'in', 'a']
# ['and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and']
# ['the', 'the', 'a', 'the', 'the', 'a', 'development', 'a', 'the', 'stephen', 'the', 'the', 'the', 'the', 'mark', 'the', 'a', 'development', 'development', 'exploration', 'the', 'a', 'gvr', 'development', 'the', 'the', 'a', 'the', 'nicholas', 'a', 'the', 'might', 'the', 'the', 'a', 'a', 'a', 'a', 'the', 'the', 'the', 'class', 'a', 'a', 'the', 'a', 'run', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'the', 'run', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'the', 'unix', 'the', 'many', 'call', 'a', 'a', 'step', 'the', 'the', 'unix', 'run', 'run', 'a', 'the', 'the', 'the', 'a', 'the', 'mark', 'the', 'reformats', 'understands', 'the', 'class', 'path', 'auto', 'the', 'call', 'the', 'a', 'the', 'the', 'make', 'path', 'class', 'a', 'the', 'raw_input', 'a', 'the', 'the', 'run', 'a', 'the', 'the', 'the', 'the', 'a', 'path', 'a', 'path', 'classes', 'a', 'the', 'class', 'a', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'make', 'a', 'a', 'a', 'the', 'the', 'auto', 'a', 'the', 'the', 'path', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'class', 'the', 'class', 'the', 'the', 'configure', 'the', 'the', 'the', 'a', 'a', 'the', 'a', 'make', 'the', 'the', 'a', 'even', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['you', 'you', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'if', 'you', 'if', 'you', 'you', 'you', 'if', 'and', 'use', 'menu', 'and', 'if', 'and', 'and', 'and', 'you', 'and', 'you', 'you', 'you', 'use', 'if', 'you', 'use', 'you', 'you', 'and', 'menu', 'and', 'and', 'and', 'you', 'and', 'users', 'and', 'you', 'use', 'you', 'use', 'menu', 'you', 'and', 'menu', 'menu', 'and', 'menu', 'menu', 'menu', 'use', 'and', 'menu', 'use', 'these', 'and', 'these', 'conventions', 'you', 'and', 'menu', 'menu', 'menu', 'menu', 'if', 'you', 'menu', 'menu', 'you', 'and', 'if', 'you']
# ['the', 'the', 'new', 'new', 'the', 'the', 'the', 'and', 'the', 'the', 'not', 'the', 'the', 'the', 'new', 'and', 'the', 'and', 'and', 'the', 'new', 'the', 'and', 'the', 'and', 'the', 'and', 'the', 'the', 'not', 'the', 'the', 'the', 'has', 'and', 'the', 'the', 'has', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'edit', 'has', 'edit', 'and', 'the', 'the', 'new', 'new', 'the', 'has', 'the', 'the', 'and', 'the', 'and', 'and', 'not', 'and', 'the', 'the', 'the', 'the', 'not', 'the', 'the', 'new', 'and', 'not', 'the', 'and', 'new', 'and', 'the', 'and', 'the', 'the', 'the', 'the', 'new', 'and', 'the', 'and', 'the', 'the', 'the', 'the', 'the', 'the', 'new', 'new', 'entry', 'and', 'the', 'entry', 'new', 'the', 'new', 'the', 'new', 'the', 'the', 'and', 'update', 'items', 'the', 'label', 'the', 'and', 'jit', 'items', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'and', 'the', 'new', 'the', 'and', 'the', 'the', 'the', 'edit', 'new', 'jit', 'the', 'zoom', 'the', 'the', 'and', 'edit', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['is', 'is', 'and', 'is', 'is', 'not', 'is', 'is', 'and', 'is', 'and', 'and', 'and', 'and', 'is', 'is', 'and', 'not', 'when', 'and', 'is', 'output', 'format', 'and', 'is', 'is', 'is', 'and', 'and', 'and', 'not', 'and', 'is', 'not', 'is', 'is', 'is', 'and', 'stack', 'stack', 'not', 'format', 'and', 'and', 'is', 'and', 'when', 'and', 'and', 'and', 'output', 'is', 're', 'and', 'is', 'when', 'and', 'stack', 'stack', 'api', 'is', 'when', 'though', 'is', 'stack', 'and', 'and', 'is', 'format', 'stack', 'stack', 'when', 'and']
# ['the', 'the', 'a', 'the', 'the', 'a', 'development', 'a', 'the', 'stephen', 'the', 'the', 'the', 'the', 'mark', 'the', 'a', 'development', 'development', 'exploration', 'the', 'a', 'gvr', 'development', 'the', 'the', 'a', 'the', 'nicholas', 'a', 'the', 'might', 'the', 'the', 'a', 'a', 'a', 'a', 'the', 'the', 'the', 'class', 'a', 'a', 'the', 'a', 'run', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'the', 'run', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'the', 'unix', 'the', 'many', 'call', 'a', 'a', 'step', 'the', 'the', 'unix', 'run', 'run', 'a', 'the', 'the', 'the', 'a', 'the', 'mark', 'the', 'reformats', 'understands', 'the', 'class', 'path', 'auto', 'the', 'call', 'the', 'a', 'the', 'the', 'make', 'path', 'class', 'a', 'the', 'raw_input', 'a', 'the', 'the', 'run', 'a', 'the', 'the', 'the', 'the', 'a', 'path', 'a', 'path', 'classes', 'a', 'the', 'class', 'a', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'make', 'a', 'a', 'a', 'the', 'the', 'auto', 'a', 'the', 'the', 'path', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'class', 'the', 'class', 'the', 'the', 'configure', 'the', 'the', 'the', 'a', 'a', 'the', 'a', 'make', 'the', 'the', 'a', 'even', 'the']
# ['file', 'previous', 'new', 'new', 'result', 'python', 'python', 'priority', 'merging', 'known', 'window', 'previous', 'well', 'new', 'remote', 'new', 'combination', 'modification', 'python', 'module', 'replacement', 'separate', 'temporary', 'file', 'system', 'system', 'module', 'traceback', 'readline', 'scroll_clear', 'previous', 'window', 'blank', 'window', 'interactive', 'window', 'file', 'blank', 'window', 'window', 'window', 'well', 'known', 'python', 'module', 'few', 'python', 'synonym', 'new', 'remote', 'new', 'python', 'window', 'window', 'readline', 'scroll_clear', 'file', 'tkinter', 'python', 'more', 'file', 'python', 'tkinter', 'window', 'python', 'python', 'window', 'k', 'interactive', 'file', 'dos', 'file', 'python', 'python', 'python', 'python', 'python', 'new', 'tree', 'paragraph', 'python', 'new', 'more', 'python', 'window', 'known', 'window', 'window', 'region', 'more', 'new', 'tree', 'script', 'more', 'python', 'window', 'reload', 'module', 'module', 'script', 'script', 'script', 'new', '4', '4', 'new', 'file', '4', 'superset', 'new', 'module', 'new', 'module', 'new', 'window', 'module', 'reload', 'module', 'torn', 'window', 'checkbox', 'quit', 'python', 'lot', 'window', 'window', 'regular', 'new', 'file', 'python', 'window', 'file', 'new', 'more', 'region', 'paragraph', 'traceback', 'window', 'regular', 'window', 'python']
# ['to', 'of', 'a', 'of', 'of', 'of', 'is', 'a', 'is', 'a', 'of', 'and', 'is', 'also', 'also', 'is', 'is', 'to', 'is', 'a', 'of', 'to', 'and', 'of', 'a', 'is', 'and', 'and', 'of', 'of', 'a', 'of', 'and', 'and', 'is', 'a', 'of', 'of', 'of', 'is', 'and', 'to', 'to', 'that', 'of', 'a', 'a', 'to', 'a', 'to', 'a', 'that', 'of', 'a', 'to', 'and', 'a', 'is', 'to', 'of', 'a', 'of', 'startup', 'a', 'rather', 'opening', 'a', 'a', 'replaces', 'of', 'that', 'instead', 'of', 'because', 'of', 'to', 'a', 'of', 'to', 'to', 'and', 'is', 'a', 'instead', 'of', 'is', 'a', 'to', 'formatparagraph', 'to', 'eol', 'startup', 'is', 'of', 'a', 'a', 'and', 'text', 'and', 'and', 'a', 'a', 'and', 'is', 'to', 'to', 'to', 'a', 'to', 'to', 'so', 'is', 'a', 'of', 'is', 'of', 'is', 'of', 'of', 'and', 'and', 'mh', 'of', 'and', 'of', 'is', 'and', 'to', 'of', 'pops', 'of', 'a', 'to', 'mh', 'to', 'and', 'a', 'that', 'to', 'to', 'to', 'and', 'to', 'a', 'to', 'to', 'a', 'also', 'to', 'a', 'a', 'and', 'a', 'of', 'also', 'a', 'a', 'to', 'a', 'pressing', 'a', 'is', 'a', 'of', 'that', 'and', 'a', 'a', 'is', 'a', 'and', 'a', 'to', 'is', 'to', 'so', 'a', 'of', 'to', 'to', 'of', 'a', 'that', 'is', 'of', 'to', 'of', 'and', 'text', 'of', 'and', 'to', 'is', 'to', 'a', 'to', 'a', 'pops', 'a', 'full', 'text', 'a', 'so', 'and']
# ['in', 'a', 'no', 'a', 'in', 'based', 'a', 'basically', 'not', 'being', 'now', 'launching', 'a', 'now', 'in', 'a', 'currently', 'in', 'in', 'a', 'a', 'alpha', 'a', 'in', 'a', 'an', 'an', 'in', 'a', 'not', 'a', 'in', 'now', 'a', 'used', 'a', 'used', 'a', 'a', 'an', 'a', 'in', 'a', 'a', 'in', 'now', 'present', 'a', 'now', 'now', 'a', 'in', 'in', 'an', 'a', 'based', 'a', 'in', 'currently', 'a', 'a', 'not', 'in', 'a', 'not', 'opened', 'currently', 'a', 'an', 'distributed', 'covered', 'in', 'used', 'not', 'now', 'reflected', 'in', 'a', 'an', 'in', 'now', 'based', 'a', 'now', 'a', 'a', 'in', 'in', 'a', 'a', 'a', 'a', 'in', 'a', 'a', 'in', 'a', 'effectively', 'a', 'a', 'a', 'opened', 'now', 'a', 'a', 'explicitly', 'still', 'a', 'in', 'a', 'still', 'now', 'in', 'in', 'in', 'now', 'now', 'in', 'in', 'a', 'a', 'in', 'a', 'now', 'in', 'a', 'distributed']
# ['file', 'previous', 'new', 'new', 'result', 'python', 'python', 'priority', 'merging', 'known', 'window', 'previous', 'well', 'new', 'remote', 'new', 'combination', 'modification', 'python', 'module', 'replacement', 'separate', 'temporary', 'file', 'system', 'system', 'module', 'traceback', 'readline', 'scroll_clear', 'previous', 'window', 'blank', 'window', 'interactive', 'window', 'file', 'blank', 'window', 'window', 'window', 'well', 'known', 'python', 'module', 'few', 'python', 'synonym', 'new', 'remote', 'new', 'python', 'window', 'window', 'readline', 'scroll_clear', 'file', 'tkinter', 'python', 'more', 'file', 'python', 'tkinter', 'window', 'python', 'python', 'window', 'k', 'interactive', 'file', 'dos', 'file', 'python', 'python', 'python', 'python', 'python', 'new', 'tree', 'paragraph', 'python', 'new', 'more', 'python', 'window', 'known', 'window', 'window', 'region', 'more', 'new', 'tree', 'script', 'more', 'python', 'window', 'reload', 'module', 'module', 'script', 'script', 'script', 'new', '4', '4', 'new', 'file', '4', 'superset', 'new', 'module', 'new', 'module', 'new', 'window', 'module', 'reload', 'module', 'torn', 'window', 'checkbox', 'quit', 'python', 'lot', 'window', 'window', 'regular', 'new', 'file', 'python', 'window', 'file', 'new', 'more', 'region', 'paragraph', 'traceback', 'window', 'regular', 'window', 'python']
# ['this', 'a', 'this', 'with', 'is', 'a', 'this', 'is', 'a', 'with', 'with', 'this', 'is', 'with', 'is', 'this', 'with', 'this', 'is', 'is', 'a', 'a', 'is', 'this', 'this', 'a', 'with', 'this', 'is', 'a', 'is', 'this', 'a', 'a', 'a', 'with', 'a', 'calls', 'a', 'a', 'is', 'a', 'with', 'a', 'a', 'a', 'a', 'is', 'a', 'is', 'a', 'with', 'name', 'with', 'this', 'is', 'a', 'a', 'with', 'with', 'a', 'a', 'is', 'a', 'is', 'with', 'a', 'is', 'with', 'this', 'is', 'this', 'is', 'name', 'a', 'a', 'a', 'this', 'name', 'control', 'a', 'this', 'name', 'a', 'a', 'a', 'a', 'multiscrolledlists', 'this', 'a', 'with', 'a', 'a', 'is', 'a', 'control', 'a', 'a', 'is', 'a', 'with', 'this', 'a', 'is', 'a', 'a', 'is', 'is', 'with', 'a', 'a', 'a', 'a', 'with']
# ['the', 'the', 'a', 'the', 'the', 'python', 'or', 'earlier', 'python', 'a', 'a', 'the', 'earlier', 'current', 'some', 'additional', 'some', 'running', 'the', 'the', 'the', 'the', 'the', 'a', 'the', 'a', 'the', 'the', 'a', 'the', 'additional', 'a', 'the', 'or', 'or', 'the', 'python', 'the', 'execbinding', 'a', 'a', 'a', 'running', 'execbinding', 'a', 'the', 'the', 'the', 'a', 'a', 'the', 'a', 'the', 'just', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'execbinding', 'running', 'additional', 'use', 'the', 'the', 'running', 'the', 'the', 'python', 'the', 'a', 'python', 'the', 'a', 'execbinding', 'execbinding', 'python', 'same', 'same', 'same', 'id', 'a', 'python', 'a', 'more', 'the', 'the', 'python', 'the', 'tcl', 'the', 'tcl', 'multiple', 'python', 'python', 'a', 'a', 'the', 'the', 'use', 'a', 'use', 'the', 'the', 'the', 'python', 'a', 'python', 'python', 'the', 'python', 'python', 'current', 'the', 'python', 'more', 'python', 'the', 'the', 'the', 'a', 'or', 'the', 'the', 'more', 'a', 'running', 'more', 'the', 'python', 'use', 'a', 'the', 'the', 'use', 'a', 'the', 'the', 'the', 'the', 'a', 'a', 'a', 'the', 'a', 'the', 'running', 'a', 'or', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'a', 'or', 'a', 'the', 'use', 'the', 'a', 'the', 'the', 'current', 'the', 'python', 'use', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'python', 'the', 'more', 'or', 'a', 'a', 'just', 'the', 'a', 'the', 'the', 'a', 'the', 'python']
# ['idle', 'this', 'the', 'idle', 'the', 'idle', 'the', 'the', 'this', 'this', 'the', 'idle', 'idle', 'idle', 'this', 'the', 'the', 'this', 'the', 'the', 'idle', 'this', 'the', 'the', 'the', 'this', 'the', 'idle', 'this', 'idle', 'the', 'idle', 'this', 'the', 'idle', 'the', 'idle', 'this', 'idle', 'the', 'idle', 'the', 'the', 'the', 'the', 'the', 'idle', 'the', 'the', 'the', 'idle', 'the', 'the', 'the', 'the', 'the', 'the', 'idle', 'idle', 'idle', 'idle', 'this', 'idle', 'the', 'idle', 'the', 'the', 'the', 'the', 'the', 'idle', 'idle', 'idle', 'the', 'idle', 'the', 'the', 'idle', 'idle', 'idle', 'this', 'idle', 'the', 'idle', 'the', 'this', 'the', 'the', 'the', 'the', 'the', 'the', 'f5', 'this', 'the', 'the', 'control', 'f5', 'this', 'the', 'the', 'the', 'the', 'idle', 'the', 'the', 'this', 'idle', 'the', 'f5', 'control', 'f5', 'the', 'the', 'the', 'this', 'the', 'the', 'the', 'the', 'canonical', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'idle', 'the', 'idle', 'the', 'the', 'the', 'the', 'the', 'the', 'idle', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['the', 'the', 'new', 'new', 'the', 'the', 'the', 'and', 'the', 'the', 'not', 'the', 'the', 'the', 'new', 'and', 'the', 'and', 'and', 'the', 'new', 'the', 'and', 'the', 'and', 'the', 'and', 'the', 'the', 'not', 'the', 'the', 'the', 'has', 'and', 'the', 'the', 'has', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'edit', 'has', 'edit', 'and', 'the', 'the', 'new', 'new', 'the', 'has', 'the', 'the', 'and', 'the', 'and', 'and', 'not', 'and', 'the', 'the', 'the', 'the', 'not', 'the', 'the', 'new', 'and', 'not', 'the', 'and', 'new', 'and', 'the', 'and', 'the', 'the', 'the', 'the', 'new', 'and', 'the', 'and', 'the', 'the', 'the', 'the', 'the', 'the', 'new', 'new', 'entry', 'and', 'the', 'entry', 'new', 'the', 'new', 'the', 'new', 'the', 'the', 'and', 'update', 'items', 'the', 'label', 'the', 'and', 'jit', 'items', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'and', 'the', 'new', 'the', 'and', 'the', 'the', 'the', 'edit', 'new', 'jit', 'the', 'zoom', 'the', 'the', 'and', 'edit', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['is', 'is', 'and', 'is', 'is', 'not', 'is', 'is', 'and', 'is', 'and', 'and', 'and', 'and', 'is', 'is', 'and', 'not', 'when', 'and', 'is', 'output', 'format', 'and', 'is', 'is', 'is', 'and', 'and', 'and', 'not', 'and', 'is', 'not', 'is', 'is', 'is', 'and', 'stack', 'stack', 'not', 'format', 'and', 'and', 'is', 'and', 'when', 'and', 'and', 'and', 'output', 'is', 're', 'and', 'is', 'when', 'and', 'stack', 'stack', 'api', 'is', 'when', 'though', 'is', 'stack', 'and', 'and', 'is', 'format', 'stack', 'stack', 'when', 'and']
# ['the', 'the', 'a', 'the', 'the', 'a', 'development', 'a', 'the', 'stephen', 'the', 'the', 'the', 'the', 'mark', 'the', 'a', 'development', 'development', 'exploration', 'the', 'a', 'gvr', 'development', 'the', 'the', 'a', 'the', 'nicholas', 'a', 'the', 'might', 'the', 'the', 'a', 'a', 'a', 'a', 'the', 'the', 'the', 'class', 'a', 'a', 'the', 'a', 'run', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'the', 'run', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'the', 'unix', 'the', 'many', 'call', 'a', 'a', 'step', 'the', 'the', 'unix', 'run', 'run', 'a', 'the', 'the', 'the', 'a', 'the', 'mark', 'the', 'reformats', 'understands', 'the', 'class', 'path', 'auto', 'the', 'call', 'the', 'a', 'the', 'the', 'make', 'path', 'class', 'a', 'the', 'raw_input', 'a', 'the', 'the', 'run', 'a', 'the', 'the', 'the', 'the', 'a', 'path', 'a', 'path', 'classes', 'a', 'the', 'class', 'a', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'make', 'a', 'a', 'a', 'the', 'the', 'auto', 'a', 'the', 'the', 'path', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'class', 'the', 'class', 'the', 'the', 'configure', 'the', 'the', 'the', 'a', 'a', 'the', 'a', 'make', 'the', 'the', 'a', 'even', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['namespace', 'namespace']
# ['the', 'you', 'you', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'you', 'you', 'you', 'the', 'you', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'you', 'you', 'you', 'you', 'the', 'the', 'you', 'the', 'you', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'you', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'the', 'the', 'you', 'the', 'the', 'you', 'you', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['and', 'and', 'and', 'and', 'and', 'and', 'and', 'has', 'and', 'has', 'has', 'and', 'has', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'browsers', 'and', 'browsers', 'and', 'browser', 'browser', 'and', 'browser', 'and', 'and', 'browser', 'and', 'browser', 'and', 'and']
# ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'been', 'the', 'the', 'been', 'the', 'the', 'the', 'the', 'the', 'the', 'been', 'the', 'been', 'the', 'been', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the']
# ['improved', 'changed', 'reorganized', 'split', 'changed', 'reorganized', 'changed']
# ['by', 'by', 'by', 'by', 'startup', 'by', 'f1', 'startup', 'by', 'by', 'by', 'by', 'by', 'by', 'by']
# ['behavior', 'behavior']
# ['has', 'has', 'has', 'readme', 'has']
# ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'been', 'the', 'the', 'been', 'the', 'the', 'the', 'the', 'the', 'the', 'been', 'the', 'been', 'the', 'been', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['and', 'and', 'and', 'and', 'and', 'and', 'and', 'has', 'and', 'has', 'has', 'and', 'has', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'browsers', 'and', 'browsers', 'and', 'browser', 'browser', 'and', 'browser', 'and', 'and', 'browser', 'and', 'browser', 'and', 'and']
# ['the', 'the', 'a', 'the', 'the', 'a', 'development', 'a', 'the', 'stephen', 'the', 'the', 'the', 'the', 'mark', 'the', 'a', 'development', 'development', 'exploration', 'the', 'a', 'gvr', 'development', 'the', 'the', 'a', 'the', 'nicholas', 'a', 'the', 'might', 'the', 'the', 'a', 'a', 'a', 'a', 'the', 'the', 'the', 'class', 'a', 'a', 'the', 'a', 'run', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'the', 'run', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'the', 'unix', 'the', 'many', 'call', 'a', 'a', 'step', 'the', 'the', 'unix', 'run', 'run', 'a', 'the', 'the', 'the', 'a', 'the', 'mark', 'the', 'reformats', 'understands', 'the', 'class', 'path', 'auto', 'the', 'call', 'the', 'a', 'the', 'the', 'make', 'path', 'class', 'a', 'the', 'raw_input', 'a', 'the', 'the', 'run', 'a', 'the', 'the', 'the', 'the', 'a', 'path', 'a', 'path', 'classes', 'a', 'the', 'class', 'a', 'the', 'a', 'the', 'a', 'a', 'a', 'the', 'the', 'make', 'a', 'a', 'a', 'the', 'the', 'auto', 'a', 'the', 'the', 'path', 'the', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'class', 'the', 'class', 'the', 'the', 'configure', 'the', 'the', 'the', 'a', 'a', 'the', 'a', 'make', 'the', 'the', 'a', 'even', 'the']
# ['file', 'previous', 'new', 'new', 'result', 'python', 'python', 'priority', 'merging', 'known', 'window', 'previous', 'well', 'new', 'remote', 'new', 'combination', 'modification', 'python', 'module', 'replacement', 'separate', 'temporary', 'file', 'system', 'system', 'module', 'traceback', 'readline', 'scroll_clear', 'previous', 'window', 'blank', 'window', 'interactive', 'window', 'file', 'blank', 'window', 'window', 'window', 'well', 'known', 'python', 'module', 'few', 'python', 'synonym', 'new', 'remote', 'new', 'python', 'window', 'window', 'readline', 'scroll_clear', 'file', 'tkinter', 'python', 'more', 'file', 'python', 'tkinter', 'window', 'python', 'python', 'window', 'k', 'interactive', 'file', 'dos', 'file', 'python', 'python', 'python', 'python', 'python', 'new', 'tree', 'paragraph', 'python', 'new', 'more', 'python', 'window', 'known', 'window', 'window', 'region', 'more', 'new', 'tree', 'script', 'more', 'python', 'window', 'reload', 'module', 'module', 'script', 'script', 'script', 'new', '4', '4', 'new', 'file', '4', 'superset', 'new', 'module', 'new', 'module', 'new', 'window', 'module', 'reload', 'module', 'torn', 'window', 'checkbox', 'quit', 'python', 'lot', 'window', 'window', 'regular', 'new', 'file', 'python', 'window', 'file', 'new', 'more', 'region', 'paragraph', 'traceback', 'window', 'regular', 'window', 'python']
# ['this', 'a', 'this', 'with', 'is', 'a', 'this', 'is', 'a', 'with', 'with', 'this', 'is', 'with', 'is', 'this', 'with', 'this', 'is', 'is', 'a', 'a', 'is', 'this', 'this', 'a', 'with', 'this', 'is', 'a', 'is', 'this', 'a', 'a', 'a', 'with', 'a', 'calls', 'a', 'a', 'is', 'a', 'with', 'a', 'a', 'a', 'a', 'is', 'a', 'is', 'a', 'with', 'name', 'with', 'this', 'is', 'a', 'a', 'with', 'with', 'a', 'a', 'is', 'a', 'is', 'with', 'a', 'is', 'with', 'this', 'is', 'this', 'is', 'name', 'a', 'a', 'a', 'this', 'name', 'control', 'a', 'this', 'name', 'a', 'a', 'a', 'a', 'multiscrolledlists', 'this', 'a', 'with', 'a', 'a', 'is', 'a', 'control', 'a', 'a', 'is', 'a', 'with', 'this', 'a', 'is', 'a', 'a', 'is', 'is', 'with', 'a', 'a', 'a', 'a', 'with']
# ['file', 'previous', 'new', 'new', 'result', 'python', 'python', 'priority', 'merging', 'known', 'window', 'previous', 'well', 'new', 'remote', 'new', 'combination', 'modification', 'python', 'module', 'replacement', 'separate', 'temporary', 'file', 'system', 'system', 'module', 'traceback', 'readline', 'scroll_clear', 'previous', 'window', 'blank', 'window', 'interactive', 'window', 'file', 'blank', 'window', 'window', 'window', 'well', 'known', 'python', 'module', 'few', 'python', 'synonym', 'new', 'remote', 'new', 'python', 'window', 'window', 'readline', 'scroll_clear', 'file', 'tkinter', 'python', 'more', 'file', 'python', 'tkinter', 'window', 'python', 'python', 'window', 'k', 'interactive', 'file', 'dos', 'file', 'python', 'python', 'python', 'python', 'python', 'new', 'tree', 'paragraph', 'python', 'new', 'more', 'python', 'window', 'known', 'window', 'window', 'region', 'more', 'new', 'tree', 'script', 'more', 'python', 'window', 'reload', 'module', 'module', 'script', 'script', 'script', 'new', '4', '4', 'new', 'file', '4', 'superset', 'new', 'module', 'new', 'module', 'new', 'window', 'module', 'reload', 'module', 'torn', 'window', 'checkbox', 'quit', 'python', 'lot', 'window', 'window', 'regular', 'new', 'file', 'python', 'window', 'file', 'new', 'more', 'region', 'paragraph', 'traceback', 'window', 'regular', 'window', 'python']
# ['idle', 'contains', 'idle', 'idle', 'in', 'with', 'in', 'idle', 'with', 'idle', 'idle', 'with', 'contains', 'with', 'with', 'idle', 'in', 'in', 'in', 'idle', 'idle', 'idle', 'with', 'idle', 'it', 'it', 'idle', 'it', 'idle', 'in', 'in', 'idle', 'it', 'it', 'with', 'in', 'it', 'it', 'idle', 'with', 'in', 'idle', 'in', 'menu', 'idle', 'in', 'idle', 'idle', 'with', 'in', 'with', 'idle', 'idle', 'changelog', 'idle', 'in', 'with', 'with', 'in', 'idle', 'it', 'idle', 'it', 'it', 'idle', 'idle', 'idle', 'idle', 'it', 'with', 'idle', 'with', 'it', 'idle', 'in', 'idle', 'it', 'menu', 'in', 'path', 'in', 'it', 'path', 'in', 'in', 'idle', 'menu', 'path', 'path', 'it', 'menu', 'in', 'idle', 'with', 'in', 'it', 'menu', 'menu', 'menu', 'menu', 'with', 'menu', 'path', 'in', 'in', 'it', 'in', 'in', 'idle', 'idle', 'menu', 'in', 'menu', 'menu', 'with', 'in', 'menu', 'in', 'menu', 'menu', 'in', 'it', 'idle', 'with']
# ['history', 'releases', 's', 'history', 's', '0', 'requires', 'is', 'is', 'fork', 'post', 'version', '0', 'is', 'is', 'fork', '0', 'is', 'is', 's', 'is', 'can', 's', '0', 'fork', '0', 'fork', 'changes', '0', 'is', 'version', '0', 'it', 'is', 'it', 'post', 'dev', 'it', 'version', 'changes', 'it', 'it', 'has', 'it', 'is', 'it', 'has', 'starts', 'can', 'has', 'is', 'help', 'is', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'bat', 'pyw', 'py', 'py', 'py', 'py', '0', 'is', 'my', 'has', 'can', 'is', 'py', 'it', 'py', 'can', 'it', 'it', 'can', 'pyw', 'bat', 'py', 'requires', 'it', 'is', 'version', 'is', 'can', 'version', 'it', 'is', '0', 'it', 'version', 'py', 's', 'is', 'it', '0', 'it', 's', 's', 'py', '0', 'changes', 'is', 'it', 'is', 'can', 'starts', 'is', 's', 'is', 'it', '0', 'changes', 'can', 'extension', 'is', 'help', 'help', 'can', 'it', '0']
# ['8', '1', '2', '1', '1', '8', '7', '1', '7', '1', '5', '7', '1', '5', '5', '1', '5', '2', '1', '5', '2', '1', '5', '2', '5', '2', '4', '4', '7', '4', '3', '2', '1', '5', '2', '1', '8', '1', '1', '5']
# ...
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['module', 'tracebacks', 'module', 'protocol', 'module', 'py', 'py', 'protocol', 'py', 'protocol', 'py', 'py', 'py', 'py', 'enabled', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'py', 'module', 'module', 'module', 'py', 'enabled', 'module', 'module', 'module']
# ['this', 'a', 'this', 'with', 'is', 'a', 'this', 'is', 'a', 'with', 'with', 'this', 'is', 'with', 'is', 'this', 'with', 'this', 'is', 'is', 'a', 'a', 'is', 'this', 'this', 'a', 'with', 'this', 'is', 'a', 'is', 'this', 'a', 'a', 'a', 'with', 'a', 'calls', 'a', 'a', 'is', 'a', 'with', 'a', 'a', 'a', 'a', 'is', 'a', 'is', 'a', 'with', 'name', 'with', 'this', 'is', 'a', 'a', 'with', 'with', 'a', 'a', 'is', 'a', 'is', 'with', 'a', 'is', 'with', 'this', 'is', 'this', 'is', 'name', 'a', 'a', 'a', 'this', 'name', 'control', 'a', 'this', 'name', 'a', 'a', 'a', 'a', 'multiscrolledlists', 'this', 'a', 'with', 'a', 'a', 'is', 'a', 'control', 'a', 'a', 'is', 'a', 'with', 'this', 'a', 'is', 'a', 'a', 'is', 'is', 'with', 'a', 'a', 'a', 'a', 'with']
# ['file', 'release', 'for', 'release', 'release', 'is', 'release', 'is', 'version', 'release', 'is', 'is', 'was', 'release', 'release', 'is', 'is', 'stage', 'is', 'release', 'was', 'release', 'stage', 'was', 'is', 'version', 'is', 'modified', 'version', 'for', 'file', 'is', 'file', 'for', 'is', 'is', 'for', 'modified', 'for', 'file', 'release', 'is', 'release', 'for', 'for', 'file', 'is', 'file', 'file', 'for', 'is', 'version', 'is', 'version', 'is', 'version', 'is', 'adds', 'runs', 'file', 'for', 'dialog', 'for', 'is', 'is', 'for', 'was', 'is', 'for', 'is', 'file', 'is', 'file', 'dialog', 'dialog', 'dialog', 'was', 'release']
# ['messages', 'on', 'of', '0', 'date', 'of', 'of', 'requires', 'of', 'is', 'is', 'on', 'of', '0', 'is', 'is', '0', 'is', 'is', 'of', 'of', 'is', 'of', 'on', '0', 'date', 'of', 'of', '0', '0', 'is', 'of', 'of', '0', 'of', 'is', 'of', 'of', 'is', 'of', 'of', 'of', 'of', 'of', 'of', 'on', 'is', 'of', 'is', 'on', '0', 'notes', 'is', 'of', 'on', 'on', 'is', 'on', 'on', 'on', 'on', 'requires', 'is', 'of', 'is', 'on', 'of', 'is', '0', 'of', 'of', 'of', 'of', 'is', 'of', 'of', 'on', '0', 'of', '0', 'is', 'of', 'is', 'is', 'of', 'of', 'is', 'of', 'of', '0', 'of', 'is', '0', 'on']
# ['idle', 'the', 'idle', 'the', 'idle', 'a', 'the', 'the', 'python', 'python', 'a', 'development', 'a', 'the', 'idle', 'work', 'idle', 'idle', 'the', 'the', 'the', 'the', 'idle', 'the', 'a', 'development', 'development', 'the', 'a', 'development', 'less', 'the', '2000', 'the', 'idle', 'a', 'idle', 'the', 'idle', 'changes', '2000', 'a', 'the', 'idle', '2000', 'it', 'it', 'the', 'python', 'idle', 'it', 'that', 'idle', 'changes', 'the', 'a', 'a', 'idle', 'it', 'a', 'it', 'a', 'the', 'that', 'the', 'the', 'it', 'a', 'a', 'the', 'a', 'it', 'the', 'idle', 'a', 'a', 'a', 'the', 'that', 'creating', 'the', 'a', 'the', 'idle', 'the', 'the', 'the', 'the', 'python', 'the', 'a', 'python', 'the', 'idle', 'a', 'python', 'idle', 'idle', 'idle', '2000', 'idle', 'a', 'python', 'a', 'the', 'idle', 'the', 'python', 'the', 'the', 'multi', 'python', 'python', 'a', 'a', 'breakpoints', 'the', 'the', 'idle', 'it', 'idle', 'it', 'it', 'idle', 'a', 'the', 'idle', 'the', 'the', 'idle', 'idle', 'python', 'it', 'a', 'python', 'idle', 'python', 'it', 'idle', 'the', 'python', 'python', 'idle', '2000', 'stuff', 'it', 'the', 'python', 'pyclbr', 'python', 'the', 'the', 'multi', 'the', 'a', 'the', 'the', 'it', 'a', 'that', 'the', 'python', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'the', 'idle', 'a', 'a', 'it', 'a', 'the', 'a', 'the', 'idle', 'changes', 'a', 'the', 'a', 'a', 'a', 'that', 'it', 'the', 'the', 'a', 'a', 'a', 'the', 'the', 'a', 'the', 'the', 'the', 'python', 'breakpoints', 'work', 'a', 'work', 'the', 'breakpoints', 'the', 'a', 'that', 'the', 'the', 'the', 'the', 'it', 'the', 'idle', 'changes', 'the', 'idle', 'the', 'the', 'python', 'the', 'a', 'a', 'the', 'a', 'the', 'the', 'a', 'it', 'idle', 'the', 'python']
# ['idle', 'file', 'release', 'previous', 'idle', 'dark', 'idle', 'idlefork', 'release', 'revitalisation', 'idlefork', 'release', 'python', 'earlier', 'python', 'idlefork', 'release', 'earlier', 'idle', 'current', 'cvs', 'idle', 'idle', 'release', 'shell', 'window', 'debugger', 'case', 'previous', 'idle', 'release', 'release', 'point', 'idlefork', 'idlefork', 'cvs', 'two', 'idlefork', 'user', 'trunk', 'idlefork', 'release', 'first', 'first', 'release', 'idle', 'idle', 'vpython', 'idle', 'idlefork', 'cvs', 'idle', 'list', 'python', 'idle', 'idle', 'execbinding', 'module', 'standard', 'rpc', 'ondemandoutputwindow', 'idle', 'file', 'execbinding', 'module', 'user', 'traceback', 'ondemandoutputwindow', 'class', 'user', 'output', 'previous', 'window', 'idle', 'window', 'window', 'file', 'window', 'nonexistent', 'window', 'window', 'need', 'execbinding', 'copy', 'idle', 'rpc', 'command', 'copy', 'menus', 'excessively', 'menu', 'python', 'windows', 'win32api', 'module', 'python', 'idle', 'help', 'execbinding', 'user', 'rpc', 'user', 'menus', 'execbinding', 'menus', 'python', 'window', 'idle', 'idle', 'name', 'window', 'file', 'idle', 'release', 'release', 'idle', 'tkinter', 'python', 'file', 'idle', 'following', 'python', 'tkinter', 'e', 'windows', 'mac', 'window', 'python', 'e', 'python', 'shell', 'window', 'debugger', 'main', 'file', 'idle', 'idle', 'shell', 'windows', 'idle', 'command', 'windows', 'batch', 'file', 'idle', 'command', 'command', 'e', 'command', 'idle', 'command', 'idle', 'python', 'python', 'idle', 'python', 'idle', 'standard', 'python', 'python', 'idle', 'current', 'stack', 'stack', 'menu', 'debugger', 'python', 'python', 'class', 'insides', 'tip', 'window', 'name', 'window', 'tip', 'window', 'class', 'windows', 'script', 'python', 'shell', 'window', 'module', 'module', 'name', '__main__', 'script', 'script', '__main__', 'latter', 'script', 'name', 'idle', 'menu', 'file', 'class', 'menu', 'module', 'framework', 'idle', 'module', 'debugger', 'output', 'window', 'module', 'module', 'debugger', 'windows', 'menu', 'windows', 'menu', 'window', 'menu', 'menu', 'debugger', 'stack', 'stack', 'menu', 'debugger', 'current', 'debugger', 'python', 'management', 'debugger', 'window', 'separator', 'two', 'list', 'class', 'window', 'debugger', 'stack', 'class', 'selection', 'windows', 'standard', 'windows', 'idle', 'highlights', 'idle', 'file', 'menu', 'command', 'python', 'shell', 'window', 'file', 'menu', 'menu', 'command', 'menu', 'stack', 'stack', 'traceback', 'windows', 'menu', 'window', 'help', 'menu', 'help', 'window', 'idle', 'python', 'release']
# ['to', 'of', 'a', 'of', 'of', 'of', 'is', 'a', 'is', 'a', 'of', 'and', 'is', 'also', 'also', 'is', 'is', 'to', 'is', 'a', 'of', 'to', 'and', 'of', 'a', 'is', 'and', 'and', 'of', 'of', 'a', 'of', 'and', 'and', 'is', 'a', 'of', 'of', 'of', 'is', 'and', 'to', 'to', 'that', 'of', 'a', 'a', 'to', 'a', 'to', 'a', 'that', 'of', 'a', 'to', 'and', 'a', 'is', 'to', 'of', 'a', 'of', 'startup', 'a', 'rather', 'opening', 'a', 'a', 'replaces', 'of', 'that', 'instead', 'of', 'because', 'of', 'to', 'a', 'of', 'to', 'to', 'and', 'is', 'a', 'instead', 'of', 'is', 'a', 'to', 'formatparagraph', 'to', 'eol', 'startup', 'is', 'of', 'a', 'a', 'and', 'text', 'and', 'and', 'a', 'a', 'and', 'is', 'to', 'to', 'to', 'a', 'to', 'to', 'so', 'is', 'a', 'of', 'is', 'of', 'is', 'of', 'of', 'and', 'and', 'mh', 'of', 'and', 'of', 'is', 'and', 'to', 'of', 'pops', 'of', 'a', 'to', 'mh', 'to', 'and', 'a', 'that', 'to', 'to', 'to', 'and', 'to', 'a', 'to', 'to', 'a', 'also', 'to', 'a', 'a', 'and', 'a', 'of', 'also', 'a', 'a', 'to', 'a', 'pressing', 'a', 'is', 'a', 'of', 'that', 'and', 'a', 'a', 'is', 'a', 'and', 'a', 'to', 'is', 'to', 'so', 'a', 'of', 'to', 'to', 'of', 'a', 'that', 'is', 'of', 'to', 'of', 'and', 'text', 'of', 'and', 'to', 'is', 'to', 'a', 'to', 'a', 'pops', 'a', 'full', 'text', 'a', 'so', 'and']
# ['you', 'you', 'is', 'is', 'is', 'window', 'is', 'is', 'is', 'is', 'is', 'is', 'you', 'you', 'you', 'you', 'module', 'module', 'part', 'is', 'window', 'window', 'window', 'window', 'window', 'window', 'module', 'is', 'is', 'window', 'window', 'is', 'window', 'window', 'you', 'is', 'you', 'you', 'you', 'you', 'you', 'is', 'is', 'you', 'is', 'is', 'window', 'you', 'window', 'window', 'looks', 'window', 'you', 'module', 'module', 'you', 'you', 'module', 'module', 'window', 'module', 'is', 'module', 'window', 'is', 'is', 'window', 'is', 'window', 'you', 'window', 'is', 'you', 'window', 'window', 'you', 'you']
# ['in', 'a', 'no', 'a', 'in', 'based', 'a', 'basically', 'not', 'being', 'now', 'launching', 'a', 'now', 'in', 'a', 'currently', 'in', 'in', 'a', 'a', 'alpha', 'a', 'in', 'a', 'an', 'an', 'in', 'a', 'not', 'a', 'in', 'now', 'a', 'used', 'a', 'used', 'a', 'a', 'an', 'a', 'in', 'a', 'a', 'in', 'now', 'present', 'a', 'now', 'now', 'a', 'in', 'in', 'an', 'a', 'based', 'a', 'in', 'currently', 'a', 'a', 'not', 'in', 'a', 'not', 'opened', 'currently', 'a', 'an', 'distributed', 'covered', 'in', 'used', 'not', 'now', 'reflected', 'in', 'a', 'an', 'in', 'now', 'based', 'a', 'now', 'a', 'a', 'in', 'in', 'a', 'a', 'a', 'a', 'in', 'a', 'a', 'in', 'a', 'effectively', 'a', 'a', 'a', 'opened', 'now', 'a', 'a', 'explicitly', 'still', 'a', 'in', 'a', 'still', 'now', 'in', 'in', 'in', 'now', 'now', 'in', 'in', 'a', 'a', 'in', 'a', 'now', 'in', 'a', 'distributed']
# ['file', 'previous', 'new', 'new', 'result', 'python', 'python', 'priority', 'merging', 'known', 'window', 'previous', 'well', 'new', 'remote', 'new', 'combination', 'modification', 'python', 'module', 'replacement', 'separate', 'temporary', 'file', 'system', 'system', 'module', 'traceback', 'readline', 'scroll_clear', 'previous', 'window', 'blank', 'window', 'interactive', 'window', 'file', 'blank', 'window', 'window', 'window', 'well', 'known', 'python', 'module', 'few', 'python', 'synonym', 'new', 'remote', 'new', 'python', 'window', 'window', 'readline', 'scroll_clear', 'file', 'tkinter', 'python', 'more', 'file', 'python', 'tkinter', 'window', 'python', 'python', 'window', 'k', 'interactive', 'file', 'dos', 'file', 'python', 'python', 'python', 'python', 'python', 'new', 'tree', 'paragraph', 'python', 'new', 'more', 'python', 'window', 'known', 'window', 'window', 'region', 'more', 'new', 'tree', 'script', 'more', 'python', 'window', 'reload', 'module', 'module', 'script', 'script', 'script', 'new', '4', '4', 'new', 'file', '4', 'superset', 'new', 'module', 'new', 'module', 'new', 'window', 'module', 'reload', 'module', 'torn', 'window', 'checkbox', 'quit', 'python', 'lot', 'window', 'window', 'regular', 'new', 'file', 'python', 'window', 'file', 'new', 'more', 'region', 'paragraph', 'traceback', 'window', 'regular', 'window', 'python']
# ['for', 's', 's', '1', '2', '1', 'especially', '1', 'shell', '1', 's', 's', '1', '1', 'org', 'using', 'for', 'for', 'documentation', 'documentation', 'for', 'documentation', 'for', 'for', 'for', 'using', 'colorizing', 'shell', 'shell', 'for', '1', '2', '1', '2', '1', '2', 'copyright', 'copyright', 'org', 'copyright', '2', 'using', 'block', 's', 'shell', 's', 's', 'for', '2', 'for', 'for', 'using', '1', 'for', 's', 'colorizing', '2', '1', 'shell', '1', '1']
# ['release', 'as', '8', 'release', 'as', 'release', 'or', '5x', 'release', '8', 'release', 'was', 'release', 'as', 'release', 'release', 'was', 'release', 'was', '5', '29', '5', 'as', 'or', 'or', '5', 'release', 'release', '5', '5', '5', '5', 'or', 'or', 'or', 'was', '5', '8', 'or', 'was', '5', 'release']
# ['2', 'and', 'and', 'and', 'and', 'and', 'and', 'updated', 'and', 'and', 'and', 'february', 'and', 'and', 'and', 'and', '2', '2', '2', '2', 'and', 'and', 'and', 'and', 'and', 'and', 'and', '2', 'and', 'and', '2b2', 'and', '2', 'and', 'and', '2b1']
# ['you', 'you', '1', '1', '1', '1', '1', '15', '1', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', '1', 'so', '1', 'distribution', '1', 'you', '15', 'you', 'you', 'you', 'you', '17', '1', 'so', '1', 'you', 'you', 'so', 'you', 'you', '1', '1']
# ['release', 'as', '8', 'release', 'as', 'release', 'or', '5x', 'release', '8', 'release', 'was', 'release', 'as', 'release', 'release', 'was', 'release', 'was', '5', '29', '5', 'as', 'or', 'or', '5', 'release', 'release', '5', '5', '5', '5', 'or', 'or', 'or', 'was', '5', '8', 'or', 'was', '5', 'release']
# ['2', 'and', 'and', 'and', 'and', 'and', 'and', 'updated', 'and', 'and', 'and', 'february', 'and', 'and', 'and', 'and', '2', '2', '2', '2', 'and', 'and', 'and', 'and', 'and', 'and', 'and', '2', 'and', 'and', '2b2', 'and', '2', 'and', 'and', '2b1']
# ['you', 'you', '1', '1', '1', '1', '1', '15', '1', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', 'you', '1', 'so', '1', 'distribution', '1', 'you', '15', 'you', 'you', 'you', 'you', '17', '1', 'so', '1', 'you', 'you', 'so', 'you', 'you', '1', '1']
# the debugger is now write and the windows menu the debugger and a window is a module with use the menu the debugger and the __main__ namespace the class has been changed startup behavior has the class and a module a file idle 0 7 1 5 and development this is now to the python using python s a window of idle has the window and unix you have a tree widget xxx only one copy of the stack viewer and the execbinding module this release of the window that is a python 1 5 2 1 5 2 you

# %%
import random
from collections import defaultdict
import re

class MarkovTextGenerator:
    def __init__(self, filename):
        self.filename = filename
        self.word_freq = defaultdict(int)
        self.words = []

    def _preprocess_text(self):
        with open(self.filename, 'r', encoding='utf-8') as file:
            text = file.read()
        self.words = re.findall(r'\b\w+\b', text.lower())

    def _compute_word_frequencies(self, chain_length):
        for i in range(len(self.words) - chain_length):
            chain = tuple(self.words[i:i+chain_length])
            next_word = self.words[i+chain_length]
            self.word_freq[(chain, next_word)] += 1

    def generate_text(self, start_words, output_length, chain_length):
        if not self.words:
            self._preprocess_text()
        if not self.word_freq:
            self._compute_word_frequencies(chain_length)

        output = list(start_words)
        current_chain = tuple(start_words)
        for _ in range(int(output_length) - len(start_words)):
            next_word_candidates = [word for word in self.words if (current_chain, word) in self.word_freq]
            if not next_word_candidates:
                break
            next_word = random.choices(next_word_candidates, weights=[self.word_freq[(current_chain, w)] for w in next_word_candidates])[0]
            output.append(next_word)
            current_chain = tuple(output[-chain_length:])

        return ' '.join(output)

# Example usage:
filename = 'HISTORY.txt'
markov_generator = MarkovTextGenerator(filename)
start_words = ['the', 'python']
output_length = 50
chain_length = 2
generated_text = markov_generator.generate_text(start_words, output_length, chain_length)
print(generated_text)
markov_generator.word_freq
# Out:
# the python shell window a k a interactive interpreter debugger not complete but you can use idle pyw to avoid popping up a dos console if you have problems or suggestions you should be able to run a script this runs the script in the class and path browsers tp
# defaultdict(int,
#             {(('idle', 'history'), 'this'): 1,
#              (('history', 'this'), 'file'): 1,
#              (('this', 'file'), 'contains'): 1,
#              (('file', 'contains'), 'the'): 1,
#              (('contains', 'the'), 'release'): 1,
#              (('the', 'release'), 'messages'): 1,
#              (('release', 'messages'), 'for'): 1,
#              (('messages', 'for'), 'previous'): 1,
#              (('for', 'previous'), 'idle'): 1,
#              (('previous', 'idle'), 'releases'): 1,
#              (('idle', 'releases'), 'as'): 1,
#              (('releases', 'as'), 'you'): 1,
#              (('as', 'you'), 'read'): 1,
#              (('you', 'read'), 'on'): 1,
#              (('read', 'on'), 'you'): 1,
#              (('on', 'you'), 'go'): 1,
#              (('you', 'go'), 'back'): 1,
#              (('go', 'back'), 'to'): 1,
#              (('back', 'to'), 'the'): 1,
#              (('to', 'the'), 'dark'): 1,
#              (('the', 'dark'), 'ages'): 1,
#              (('dark', 'ages'), 'of'): 1,
#              (('ages', 'of'), 'idle'): 1,
#              (('of', 'idle'), 's'): 1,
#              (('idle', 's'), 'history'): 1,
#              (('s', 'history'), 'what'): 1,
#              (('history', 'what'), 's'): 1,
#              (('what', 's'), 'new'): 2,
#              (('s', 'new'), 'in'): 2,
#              (('new', 'in'), 'idlefork'): 2,
#              (('in', 'idlefork'), '0'): 2,
#              (('idlefork', '0'), '8'): 1,
#              (('0', '8'), '1'): 1,
#              (('8', '1'), 'release'): 1,
#              (('1', 'release'), 'date'): 2,
#              (('release', 'date'), '22'): 1,
#              (('date', '22'), 'jul'): 1,
#              (('22', 'jul'), '2001'): 1,
#              (('jul', '2001'), 'new'): 1,
#              (('2001', 'new'), 'tarball'): 1,
#              (('new', 'tarball'), 'released'): 1,
#              (('tarball', 'released'), 'as'): 1,
#              (('released', 'as'), 'a'): 1,
#              (('as', 'a'), 'result'): 1,
#              (('a', 'result'), 'of'): 1,
#              (('result', 'of'), 'the'): 1,
#              (('of', 'the'), 'revitalisation'): 1,
#              (('the', 'revitalisation'), 'of'): 1,
#              (('revitalisation', 'of'), 'the'): 1,
#              (('of', 'the'), 'idlefork'): 1,
#              (('the', 'idlefork'), 'project'): 1,
#              (('idlefork', 'project'), 'this'): 1,
#              (('project', 'this'), 'release'): 1,
#              (('this', 'release'), 'requires'): 1,
#              (('release', 'requires'), 'python'): 1,
#              (('requires', 'python'), '2'): 1,
#              (('python', '2'), '1'): 1,
#              (('2', '1'), 'or'): 1,
#              (('1', 'or'), 'better'): 1,
#              (('or', 'better'), 'compatibility'): 1,
#              (('better', 'compatibility'), 'with'): 1,
#              (('compatibility', 'with'), 'earlier'): 1,
#              (('with', 'earlier'), 'versions'): 1,
#              (('earlier', 'versions'), 'of'): 1,
#              (('versions', 'of'), 'python'): 1,
#              (('of', 'python'), 'especially'): 1,
#              (('python', 'especially'), 'ancient'): 1,
#              (('especially', 'ancient'), 'ones'): 1,
#              (('ancient', 'ones'), 'like'): 1,
#              (('ones', 'like'), '1'): 1,
#              (('like', '1'), '5x'): 1,
#              (('1', '5x'), 'is'): 1,
#              (('5x', 'is'), 'no'): 1,
#              (('is', 'no'), 'longer'): 1,
#              (('no', 'longer'), 'a'): 1,
#              (('longer', 'a'), 'priority'): 1,
#              (('a', 'priority'), 'in'): 1,
#              (('priority', 'in'), 'idlefork'): 1,
#              (('in', 'idlefork'), 'development'): 1,
#              (('idlefork', 'development'), 'this'): 1,
#              (('development', 'this'), 'release'): 1,
#              (('this', 'release'), 'is'): 3,
#              (('release', 'is'), 'based'): 1,
#              (('is', 'based'), 'on'): 1,
#              (('based', 'on'), 'a'): 2,
#              (('on', 'a'), 'merging'): 1,
#              (('a', 'merging'), 'of'): 1,
#              (('merging', 'of'), 'the'): 1,
#              (('of', 'the'), 'earlier'): 1,
#              (('the', 'earlier'), 'idle'): 1,
#              (('earlier', 'idle'), 'fork'): 1,
#              (('idle', 'fork'), 'work'): 1,
#              (('fork', 'work'), 'with'): 1,
#              (('work', 'with'), 'current'): 1,
#              (('with', 'current'), 'cvs'): 1,
#              (('current', 'cvs'), 'idle'): 1,
#              (('cvs', 'idle'), 'post'): 1,
#              (('idle', 'post'), 'idle'): 1,
#              (('post', 'idle'), 'version'): 1,
#              (('idle', 'version'), '0'): 1,
#              (('version', '0'), '8'): 1,
#              (('0', '8'), 'with'): 1,
#              (('8', 'with'), 'some'): 1,
#              (('with', 'some'), 'minor'): 1,
#              (('some', 'minor'), 'additional'): 1,
#              (('minor', 'additional'), 'coding'): 1,
#              (('additional', 'coding'), 'by'): 1,
#              (('coding', 'by'), 'kurt'): 1,
#              (('by', 'kurt'), 'b'): 1,
#              (('kurt', 'b'), 'kaiser'): 1,
#              (('b', 'kaiser'), 'and'): 1,
#              (('kaiser', 'and'), 'stephen'): 1,
#              (('and', 'stephen'), 'm'): 1,
#              (('stephen', 'm'), 'gava'): 1,
#              (('m', 'gava'), 'this'): 1,
#              (('gava', 'this'), 'release'): 1,
#              (('release', 'is'), 'basically'): 1,
#              (('is', 'basically'), 'functional'): 1,
#              (('basically', 'functional'), 'but'): 1,
#              (('functional', 'but'), 'also'): 1,
#              (('but', 'also'), 'contains'): 1,
#              (('also', 'contains'), 'some'): 1,
#              (('contains', 'some'), 'known'): 1,
#              (('some', 'known'), 'breakages'): 1,
#              (('known', 'breakages'), 'particularly'): 1,
#              (('breakages', 'particularly'), 'with'): 1,
#              (('particularly', 'with'), 'running'): 1,
#              (('with', 'running'), 'things'): 1,
#              (('running', 'things'), 'from'): 1,
#              (('things', 'from'), 'the'): 1,
#              (('from', 'the'), 'shell'): 1,
#              (('the', 'shell'), 'window'): 1,
#              (('shell', 'window'), 'also'): 1,
#              (('window', 'also'), 'the'): 1,
#              (('also', 'the'), 'debugger'): 1,
#              (('the', 'debugger'), 'is'): 1,
#              (('debugger', 'is'), 'not'): 1,
#              (('is', 'not'), 'working'): 1,
#              (('not', 'working'), 'but'): 1,
#              (('working', 'but'), 'i'): 1,
#              (('but', 'i'), 'believe'): 1,
#              (('i', 'believe'), 'this'): 1,
#              (('believe', 'this'), 'was'): 1,
#              (('this', 'was'), 'the'): 2,
#              (('was', 'the'), 'case'): 1,
#              (('the', 'case'), 'with'): 1,
#              (('case', 'with'), 'the'): 1,
#              (('with', 'the'), 'previous'): 1,
#              (('the', 'previous'), 'idle'): 1,
#              (('previous', 'idle'), 'fork'): 1,
#              (('idle', 'fork'), 'release'): 1,
#              (('fork', 'release'), '0'): 1,
#              (('release', '0'), '7'): 1,
#              (('0', '7'), '1'): 3,
#              (('7', '1'), 'as'): 1,
#              (('1', 'as'), 'well'): 1,
#              (('as', 'well'), 'this'): 1,
#              (('well', 'this'), 'release'): 1,
#              (('release', 'is'), 'being'): 1,
#              (('is', 'being'), 'made'): 1,
#              (('being', 'made'), 'now'): 1,
#              (('made', 'now'), 'to'): 1,
#              (('now', 'to'), 'mark'): 1,
#              (('to', 'mark'), 'the'): 1,
#              (('mark', 'the'), 'point'): 1,
#              (('the', 'point'), 'at'): 1,
#              (('point', 'at'), 'which'): 1,
#              (('at', 'which'), 'idlefork'): 1,
#              (('which', 'idlefork'), 'is'): 1,
#              (('idlefork', 'is'), 'launching'): 1,
#              (('is', 'launching'), 'into'): 1,
#              (('launching', 'into'), 'a'): 1,
#              (('into', 'a'), 'new'): 1,
#              (('a', 'new'), 'stage'): 1,
#              (('new', 'stage'), 'of'): 1,
#              (('stage', 'of'), 'development'): 1,
#              (('of', 'development'), 'idlefork'): 1,
#              (('development', 'idlefork'), 'cvs'): 1,
#              (('idlefork', 'cvs'), 'will'): 1,
#              (('cvs', 'will'), 'now'): 1,
#              (('will', 'now'), 'be'): 1,
#              (('now', 'be'), 'branched'): 1,
#              (('be', 'branched'), 'to'): 1,
#              (('branched', 'to'), 'enable'): 1,
#              (('to', 'enable'), 'further'): 1,
#              (('enable', 'further'), 'development'): 1,
#              (('further', 'development'), 'and'): 1,
#              (('development', 'and'), 'exploration'): 1,
#              (('and', 'exploration'), 'of'): 1,
#              (('exploration', 'of'), 'the'): 1,
#              (('of', 'the'), 'two'): 1,
#              (('the', 'two'), 'execution'): 1,
#              (('two', 'execution'), 'in'): 1,
#              (('execution', 'in'), 'a'): 1,
#              (('in', 'a'), 'remote'): 1,
#              (('a', 'remote'), 'process'): 1,
#              (('remote', 'process'), 'patches'): 1,
#              (('process', 'patches'), 'submitted'): 1,
#              (('patches', 'submitted'), 'by'): 1,
#              (('submitted', 'by'), 'david'): 1,
#              (('by', 'david'), 'scherer'): 2,
#              (('david', 'scherer'), 'david'): 1,
#              (('scherer', 'david'), 's'): 1,
#              (('david', 's'), 'is'): 1,
#              (('s', 'is'), 'currently'): 1,
#              (('is', 'currently'), 'in'): 1,
#              (('currently', 'in'), 'idlefork'): 1,
#              (('in', 'idlefork'), 'and'): 1,
#              (('idlefork', 'and'), 'gvr'): 1,
#              (('and', 'gvr'), 'while'): 1,
#              (('gvr', 'while'), 'stabilisation'): 1,
#              (('while', 'stabilisation'), 'and'): 1,
#              (('stabilisation', 'and'), 'development'): 1,
#              (('and', 'development'), 'of'): 1,
#              (('development', 'of'), 'less'): 1,
#              (('of', 'less'), 'heavyweight'): 1,
#              (('less', 'heavyweight'), 'improvements'): 1,
#              (('heavyweight', 'improvements'), 'like'): 1,
#              (('improvements', 'like'), 'user'): 1,
#              (('like', 'user'), 'customisation'): 1,
#              (('user', 'customisation'), 'can'): 1,
#              (('customisation', 'can'), 'continue'): 1,
#              (('can', 'continue'), 'on'): 1,
#              (('continue', 'on'), 'the'): 1,
#              (('on', 'the'), 'trunk'): 1,
#              (('the', 'trunk'), 'what'): 1,
#              (('trunk', 'what'), 's'): 1,
#              (('idlefork', '0'), '7'): 2,
#              (('7', '1'), 'release'): 1,
#              (('release', 'date'), '15'): 1,
#              (('date', '15'), 'aug'): 1,
#              (('15', 'aug'), '2000'): 1,
#              (('aug', '2000'), 'first'): 1,
#              (('2000', 'first'), 'project'): 1,
#              (('first', 'project'), 'tarball'): 1,
#              (('project', 'tarball'), 'released'): 1,
#              (('tarball', 'released'), 'this'): 1,
#              (('released', 'this'), 'was'): 1,
#              (('was', 'the'), 'first'): 1,
#              (('the', 'first'), 'release'): 1,
#              (('first', 'release'), 'of'): 1,
#              (('release', 'of'), 'idle'): 2,
#              (('of', 'idle'), 'fork'): 1,
#              (('idle', 'fork'), 'which'): 1,
#              (('fork', 'which'), 'at'): 1,
#              (('which', 'at'), 'this'): 1,
#              (('at', 'this'), 'stage'): 1,
#              (('this', 'stage'), 'was'): 1,
#              (('stage', 'was'), 'a'): 1,
#              (('was', 'a'), 'combination'): 1,
#              (('a', 'combination'), 'of'): 1,
#              (('combination', 'of'), 'idle'): 1,
#              (('of', 'idle'), '0'): 2,
#              (('idle', '0'), '5'): 4,
#              (('0', '5'), 'and'): 1,
#              (('5', 'and'), 'the'): 1,
#              (('and', 'the'), 'vpython'): 1,
#              (('the', 'vpython'), 'idle'): 1,
#              (('vpython', 'idle'), 'fork'): 1,
#              (('idle', 'fork'), 'with'): 1,
#              (('fork', 'with'), 'additional'): 1,
#              (('with', 'additional'), 'changes'): 1,
#              (('additional', 'changes'), 'coded'): 1,
#              (('changes', 'coded'), 'by'): 1,
#              (('coded', 'by'), 'david'): 1,
#              (('david', 'scherer'), 'peter'): 1,
#              (('scherer', 'peter'), 'schneider'): 1,
#              (('peter', 'schneider'), 'kamp'): 1,
#              (('schneider', 'kamp'), 'and'): 1,
#              (('kamp', 'and'), 'nicholas'): 1,
#              (('and', 'nicholas'), 'riley'): 1,
#              (('nicholas', 'riley'), 'idlefork'): 1,
#              (('riley', 'idlefork'), '0'): 1,
#              (('7', '1'), '29'): 1,
#              (('1', '29'), 'may'): 1,
#              (('29', 'may'), '2000'): 1,
#              (('may', '2000'), 'david'): 1,
#              (('2000', 'david'), 'scherer'): 1,
#              (('david', 'scherer'), 'dscherer'): 1,
#              (('scherer', 'dscherer'), 'cmu'): 1,
#              (('dscherer', 'cmu'), 'edu'): 1,
#              (('cmu', 'edu'), 'this'): 1,
#              (('edu', 'this'), 'is'): 1,
#              (('this', 'is'), 'a'): 1,
#              (('is', 'a'), 'modification'): 1,
#              (('a', 'modification'), 'of'): 1,
#              (('modification', 'of'), 'the'): 1,
#              (('of', 'the'), 'cvs'): 1,
#              (('the', 'cvs'), 'version'): 1,
#              (('cvs', 'version'), 'of'): 1,
#              (('version', 'of'), 'idle'): 3,
#              (('0', '5'), 'updated'): 1,
#              (('5', 'updated'), 'as'): 1,
#              (('updated', 'as'), 'of'): 1,
#              (('as', 'of'), '2000'): 1,
#              (('of', '2000'), '03'): 1,
#              (('2000', '03'), '09'): 1,
#              (('03', '09'), 'it'): 1,
#              (('09', 'it'), 'is'): 1,
#              (('it', 'is'), 'alpha'): 1,
#              (('is', 'alpha'), 'software'): 1,
#              (('alpha', 'software'), 'and'): 1,
#              (('software', 'and'), 'might'): 1,
#              (('and', 'might'), 'be'): 1,
#              (('might', 'be'), 'unstable'): 1,
#              (('be', 'unstable'), 'if'): 1,
#              (('unstable', 'if'), 'it'): 1,
#              (('if', 'it'), 'breaks'): 1,
#              (('it', 'breaks'), 'you'): 1,
#              (('breaks', 'you'), 'get'): 1,
#              (('you', 'get'), 'to'): 1,
#              (('get', 'to'), 'keep'): 1,
#              (('to', 'keep'), 'both'): 1,
#              (('keep', 'both'), 'pieces'): 1,
#              (('both', 'pieces'), 'if'): 1,
#              (('pieces', 'if'), 'you'): 1,
#              (('if', 'you'), 'have'): 1,
#              (('you', 'have'), 'problems'): 1,
#              (('have', 'problems'), 'or'): 1,
#              (('problems', 'or'), 'suggestions'): 1,
#              (('or', 'suggestions'), 'you'): 1,
#              (('suggestions', 'you'), 'should'): 1,
#              (('you', 'should'), 'either'): 1,
#              (('should', 'either'), 'contact'): 1,
#              (('either', 'contact'), 'me'): 1,
#              (('contact', 'me'), 'or'): 1,
#              (('me', 'or'), 'post'): 1,
#              (('or', 'post'), 'to'): 1,
#              (('post', 'to'), 'the'): 1,
#              (('to', 'the'), 'list'): 1,
#              (('the', 'list'), 'at'): 1,
#              (('list', 'at'), 'http'): 1,
#              (('at', 'http'), 'www'): 1,
#              (('http', 'www'), 'python'): 2,
#              (('www', 'python'), 'org'): 2,
#              (('python', 'org'), 'mailman'): 1,
#              (('org', 'mailman'), 'listinfo'): 1,
#              (('mailman', 'listinfo'), 'idle'): 1,
#              (('listinfo', 'idle'), 'dev'): 1,
#              (('idle', 'dev'), 'making'): 1,
#              (('dev', 'making'), 'it'): 1,
#              (('making', 'it'), 'clear'): 1,
#              (('it', 'clear'), 'that'): 1,
#              (('clear', 'that'), 'you'): 1,
#              (('that', 'you'), 'are'): 1,
#              (('you', 'are'), 'using'): 1,
#              (('are', 'using'), 'this'): 1,
#              (('using', 'this'), 'modified'): 1,
#              (('this', 'modified'), 'version'): 1,
#              (('modified', 'version'), 'of'): 1,
#              (('of', 'idle'), 'changes'): 1,
#              (('idle', 'changes'), 'the'): 1,
#              (('changes', 'the'), 'execbinding'): 1,
#              (('the', 'execbinding'), 'module'): 1,
#              (('execbinding', 'module'), 'a'): 1,
#              (('module', 'a'), 'replacement'): 1,
#              (('a', 'replacement'), 'for'): 1,
#              (('replacement', 'for'), 'scriptbinding'): 1,
#              (('for', 'scriptbinding'), 'executes'): 1,
#              (('scriptbinding', 'executes'), 'programs'): 1,
#              (('executes', 'programs'), 'in'): 1,
#              (('programs', 'in'), 'a'): 1,
#              (('in', 'a'), 'separate'): 1,
#              (('a', 'separate'), 'process'): 1,
#              (('separate', 'process'), 'piping'): 1,
#              (('process', 'piping'), 'standard'): 1,
#              (('piping', 'standard'), 'i'): 1,
#              (('standard', 'i'), 'o'): 1,
#              (('i', 'o'), 'through'): 1,
#              (('o', 'through'), 'an'): 1,
#              (('through', 'an'), 'rpc'): 1,
#              (('an', 'rpc'), 'mechanism'): 1,
#              (('rpc', 'mechanism'), 'to'): 2,
#              (('mechanism', 'to'), 'an'): 1,
#              (('to', 'an'), 'ondemandoutputwindow'): 1,
#              (('an', 'ondemandoutputwindow'), 'in'): 1,
#              (('ondemandoutputwindow', 'in'), 'idle'): 1,
#              (('in', 'idle'), 'it'): 1,
#              (('idle', 'it'), 'supports'): 1,
#              (('it', 'supports'), 'executing'): 1,
#              (('supports', 'executing'), 'unnamed'): 1,
#              (('executing', 'unnamed'), 'programs'): 1,
#              (('unnamed', 'programs'), 'through'): 1,
#              (('programs', 'through'), 'a'): 1,
#              (('through', 'a'), 'temporary'): 1,
#              (('a', 'temporary'), 'file'): 1,
#              (('temporary', 'file'), 'it'): 1,
#              (('file', 'it'), 'does'): 1,
#              (('it', 'does'), 'not'): 1,
#              (('does', 'not'), 'yet'): 1,
#              (('not', 'yet'), 'support'): 1,
#              (('yet', 'support'), 'debugging'): 1,
#              (('support', 'debugging'), 'when'): 1,
#              (('debugging', 'when'), 'running'): 1,
#              (('when', 'running'), 'programs'): 1,
#              (('running', 'programs'), 'with'): 1,
#              (('programs', 'with'), 'execbinding'): 1,
#              (('with', 'execbinding'), 'tracebacks'): 1,
#              (('execbinding', 'tracebacks'), 'will'): 1,
#              (('tracebacks', 'will'), 'be'): 1,
#              (('will', 'be'), 'clipped'): 1,
#              (('be', 'clipped'), 'to'): 1,
#              (('clipped', 'to'), 'exclude'): 1,
#              (('to', 'exclude'), 'system'): 1,
#              (('exclude', 'system'), 'modules'): 1,
#              (('system', 'modules'), 'if'): 1,
#              (('modules', 'if'), 'however'): 1,
#              (('if', 'however'), 'a'): 1,
#              (('however', 'a'), 'system'): 1,
#              (('a', 'system'), 'module'): 1,
#              (('system', 'module'), 'calls'): 1,
#              (('module', 'calls'), 'back'): 1,
#              (('calls', 'back'), 'into'): 1,
#              (('back', 'into'), 'the'): 1,
#              (('into', 'the'), 'user'): 1,
#              (('the', 'user'), 'program'): 1,
#              (('user', 'program'), 'that'): 1,
#              (('program', 'that'), 'part'): 1,
#              (('that', 'part'), 'of'): 1,
#              (('part', 'of'), 'the'): 1,
#              (('of', 'the'), 'traceback'): 1,
#              (('the', 'traceback'), 'will'): 1,
#              (('traceback', 'will'), 'be'): 1,
#              (('will', 'be'), 'shown'): 1,
#              (('be', 'shown'), 'the'): 1,
#              (('shown', 'the'), 'ondemandoutputwindow'): 1,
#              (('the', 'ondemandoutputwindow'), 'class'): 1,
#              (('ondemandoutputwindow', 'class'), 'has'): 1,
#              (('class', 'has'), 'been'): 1,
#              (('has', 'been'), 'improved'): 1,
#              (('been', 'improved'), 'in'): 1,
#              (('improved', 'in'), 'particular'): 1,
#              (('in', 'particular'), 'it'): 1,
#              (('particular', 'it'), 'now'): 1,
#              (('it', 'now'), 'supports'): 1,
#              (('now', 'supports'), 'a'): 1,
#              (('supports', 'a'), 'readline'): 1,
#              (('a', 'readline'), 'function'): 1,
#              (('readline', 'function'), 'used'): 1,
#              (('function', 'used'), 'to'): 1,
#              (('used', 'to'), 'implement'): 1,
#              (('to', 'implement'), 'user'): 1,
#              (('implement', 'user'), 'input'): 1,
#              (('user', 'input'), 'and'): 1,
#              (('input', 'and'), 'a'): 1,
#              (('and', 'a'), 'scroll_clear'): 1,
#              (('a', 'scroll_clear'), 'operation'): 1,
#              (('scroll_clear', 'operation'), 'which'): 1,
#              (('operation', 'which'), 'is'): 1,
#              (('which', 'is'), 'used'): 1,
#              (('is', 'used'), 'to'): 1,
#              (('used', 'to'), 'hide'): 1,
#              (('to', 'hide'), 'the'): 1,
#              (('hide', 'the'), 'output'): 1,
#              (('the', 'output'), 'of'): 1,
#              (('output', 'of'), 'a'): 1,
#              (('of', 'a'), 'previous'): 1,
#              (('a', 'previous'), 'run'): 1,
#              (('previous', 'run'), 'by'): 1,
#              (('run', 'by'), 'scrolling'): 1,
#              (('by', 'scrolling'), 'it'): 1,
#              (('scrolling', 'it'), 'out'): 1,
#              (('it', 'out'), 'of'): 1,
#              (('out', 'of'), 'the'): 1,
#              (('of', 'the'), 'window'): 1,
#              (('the', 'window'), 'startup'): 1,
#              (('window', 'startup'), 'behavior'): 1,
#              (('startup', 'behavior'), 'has'): 1,
#              (('behavior', 'has'), 'been'): 1,
#              (('has', 'been'), 'changed'): 1,
#              (('been', 'changed'), 'by'): 1,
#              (('changed', 'by'), 'default'): 1,
#              (('by', 'default'), 'idle'): 1,
#              (('default', 'idle'), 'starts'): 1,
#              (('idle', 'starts'), 'up'): 1,
#              (('starts', 'up'), 'with'): 1,
#              (('up', 'with'), 'just'): 1,
#              (('with', 'just'), 'a'): 1,
#              (('just', 'a'), 'blank'): 1,
#              (('a', 'blank'), 'editor'): 1,
#              (('blank', 'editor'), 'window'): 1,
#              (('editor', 'window'), 'rather'): 1,
#              (('window', 'rather'), 'than'): 1,
#              (('rather', 'than'), 'an'): 1,
#              (('than', 'an'), 'interactive'): 1,
#              (('an', 'interactive'), 'window'): 1,
#              (('interactive', 'window'), 'opening'): 1,
#              (('window', 'opening'), 'a'): 1,
#              (('opening', 'a'), 'file'): 1,
#              (('a', 'file'), 'in'): 1,
#              (('file', 'in'), 'such'): 1,
#              (('in', 'such'), 'a'): 1,
#              (('such', 'a'), 'blank'): 1,
#              (('a', 'blank'), 'window'): 1,
#              (('blank', 'window'), 'replaces'): 1,
#              (('window', 'replaces'), 'the'): 1,
#              (('replaces', 'the'), 'nonexistent'): 1,
#              (('the', 'nonexistent'), 'contents'): 1,
#              (('nonexistent', 'contents'), 'of'): 1,
#              (('contents', 'of'), 'that'): 1,
#              (('of', 'that'), 'window'): 1,
#              (('that', 'window'), 'instead'): 1,
#              (('window', 'instead'), 'of'): 1,
#              (('instead', 'of'), 'creating'): 1,
#              (('of', 'creating'), 'another'): 1,
#              (('creating', 'another'), 'window'): 1,
#              (('another', 'window'), 'because'): 1,
#              (('window', 'because'), 'of'): 1,
#              (('because', 'of'), 'the'): 1,
#              (('of', 'the'), 'need'): 1,
#              (('the', 'need'), 'to'): 1,
#              (('need', 'to'), 'have'): 1,
#              (('to', 'have'), 'a'): 1,
#              (('have', 'a'), 'well'): 1,
#              (('a', 'well'), 'known'): 1,
#              (('well', 'known'), 'port'): 1,
#              (('known', 'port'), 'for'): 1,
#              (('port', 'for'), 'the'): 1,
#              (('for', 'the'), 'execbinding'): 1,
#              (('the', 'execbinding'), 'protocol'): 1,
#              (('execbinding', 'protocol'), 'only'): 1,
#              (('protocol', 'only'), 'one'): 1,
#              (('only', 'one'), 'copy'): 1,
#              (('one', 'copy'), 'of'): 1,
#              (('copy', 'of'), 'idle'): 1,
#              (('of', 'idle'), 'can'): 1,
#              (('idle', 'can'), 'be'): 1,
#              (('can', 'be'), 'running'): 1,
#              (('be', 'running'), 'additional'): 1,
#              (('running', 'additional'), 'invocations'): 1,
#              (('additional', 'invocations'), 'use'): 1,
#              (('invocations', 'use'), 'the'): 1,
#              (('use', 'the'), 'rpc'): 1,
#              (('the', 'rpc'), 'mechanism'): 1,
#              (('mechanism', 'to'), 'report'): 1,
#              (('to', 'report'), 'their'): 1,
#              (('report', 'their'), 'command'): 1,
#              (('their', 'command'), 'line'): 1,
#              (('command', 'line'), 'arguments'): 3,
#              (('line', 'arguments'), 'to'): 1,
#              (('arguments', 'to'), 'the'): 1,
#              (('to', 'the'), 'copy'): 1,
#              (('the', 'copy'), 'already'): 1,
#              (('copy', 'already'), 'running'): 1,
#              (('already', 'running'), 'the'): 1,
#              (('running', 'the'), 'menus'): 1,
#              (('the', 'menus'), 'have'): 1,
#              (('menus', 'have'), 'been'): 1,
#              (('have', 'been'), 'reorganized'): 1,
#              (('been', 'reorganized'), 'in'): 1,
#              (('reorganized', 'in'), 'particular'): 1,
#              (('in', 'particular'), 'the'): 1,
#              (('particular', 'the'), 'excessively'): 1,
#              (('the', 'excessively'), 'large'): 1,
#              (('excessively', 'large'), 'edit'): 1,
#              (('large', 'edit'), 'menu'): 1,
#              (('edit', 'menu'), 'has'): 1,
#              (('menu', 'has'), 'been'): 1,
#              (('has', 'been'), 'split'): 1,
#              (('been', 'split'), 'up'): 1,
#              (('split', 'up'), 'into'): 1,
#              (('up', 'into'), 'edit'): 1,
#              (('into', 'edit'), 'format'): 1,
#              (('edit', 'format'), 'and'): 1,
#              (('format', 'and'), 'run'): 1,
#              (('and', 'run'), 'python'): 1,
#              (('run', 'python'), 'documentation'): 1,
#              (('python', 'documentation'), 'now'): 1,
#              (('documentation', 'now'), 'works'): 1,
#              (('now', 'works'), 'on'): 1,
#              (('works', 'on'), 'windows'): 2,
#              (('on', 'windows'), 'if'): 1,
#              (('windows', 'if'), 'the'): 1,
#              (('if', 'the'), 'win32api'): 1,
#              (('the', 'win32api'), 'module'): 1,
#              (('win32api', 'module'), 'is'): 1,
#              (('module', 'is'), 'present'): 1,
#              (('is', 'present'), 'a'): 1,
#              (('present', 'a'), 'few'): 1,
#              (('a', 'few'), 'key'): 1,
#              (('few', 'key'), 'bindings'): 1,
#              (('key', 'bindings'), 'have'): 1,
#              (('bindings', 'have'), 'been'): 1,
#              (('have', 'been'), 'changed'): 1,
#              (('been', 'changed'), 'f1'): 1,
#              (('changed', 'f1'), 'now'): 1,
#              (('f1', 'now'), 'loads'): 1,
#              (('now', 'loads'), 'python'): 1,
#              (('loads', 'python'), 'documentation'): 1,
#              (('python', 'documentation'), 'instead'): 1,
#              (('documentation', 'instead'), 'of'): 1,
#              (('instead', 'of'), 'the'): 1,
#              (('of', 'the'), 'idle'): 1,
#              (('the', 'idle'), 'help'): 1,
#              (('idle', 'help'), 'shift'): 1,
#              (('help', 'shift'), 'tab'): 1,
#              (('shift', 'tab'), 'is'): 1,
#              (('tab', 'is'), 'now'): 1,
#              (('is', 'now'), 'a'): 1,
#              (('now', 'a'), 'synonym'): 1,
#              (('a', 'synonym'), 'for'): 1,
#              (('synonym', 'for'), 'unindent'): 1,
#              (('for', 'unindent'), 'new'): 1,
#              (('unindent', 'new'), 'modules'): 1,
#              (('new', 'modules'), 'execbinding'): 1,
#              (('modules', 'execbinding'), 'py'): 1,
#              (('execbinding', 'py'), 'executes'): 1,
#              (('py', 'executes'), 'program'): 1,
#              (('executes', 'program'), 'through'): 1,
#              (('program', 'through'), 'loader'): 1,
#              (('through', 'loader'), 'loader'): 1,
#              (('loader', 'loader'), 'py'): 1,
#              (('loader', 'py'), 'bootstraps'): 1,
#              (('py', 'bootstraps'), 'user'): 1,
#              (('bootstraps', 'user'), 'program'): 1,
#              (('user', 'program'), 'protocol'): 1,
#              (('program', 'protocol'), 'py'): 1,
#              (('protocol', 'py'), 'rpc'): 1,
#              (('py', 'rpc'), 'protocol'): 1,
#              (('rpc', 'protocol'), 'remote'): 1,
#              (('protocol', 'remote'), 'py'): 1,
#              (('remote', 'py'), 'user'): 1,
#              (('py', 'user'), 'process'): 1,
#              (('user', 'process'), 'interpreter'): 1,
#              (('process', 'interpreter'), 'spawn'): 1,
#              (('interpreter', 'spawn'), 'py'): 1,
#              (('spawn', 'py'), 'os'): 1,
#              (('py', 'os'), 'specific'): 1,
#              (('os', 'specific'), 'code'): 1,
#              (('specific', 'code'), 'to'): 1,
#              (('code', 'to'), 'start'): 1,
#              (('to', 'start'), 'programs'): 1,
#              (('start', 'programs'), 'files'): 1,
#              (('programs', 'files'), 'modified'): 1,
#              (('files', 'modified'), 'autoindent'): 1,
#              (('modified', 'autoindent'), 'py'): 1,
#              (('autoindent', 'py'), 'bindings'): 1,
#              (('py', 'bindings'), 'tweaked'): 3,
#              (('bindings', 'tweaked'), 'bindings'): 1,
#              (('tweaked', 'bindings'), 'py'): 1,
#              (('bindings', 'py'), 'menus'): 1,
#              (('py', 'menus'), 'reorganized'): 1,
#              (('menus', 'reorganized'), 'config'): 1,
#              (('reorganized', 'config'), 'txt'): 1,
#              (('config', 'txt'), 'execbinding'): 1,
#              (('txt', 'execbinding'), 'enabled'): 1,
#              (('execbinding', 'enabled'), 'editorwindow'): 1,
#              (('enabled', 'editorwindow'), 'py'): 1,
#              (('editorwindow', 'py'), 'new'): 1,
#              (('py', 'new'), 'menus'): 1,
#              (('new', 'menus'), 'fixed'): 1,
#              (('menus', 'fixed'), 'python'): 1,
#              (('fixed', 'python'), 'documentation'): 1,
#              (('python', 'documentation'), 'filelist'): 1,
#              (('documentation', 'filelist'), 'py'): 1,
#              (('filelist', 'py'), 'hook'): 1,
#              (('py', 'hook'), 'for'): 1,
#              (('hook', 'for'), 'open'): 1,
#              (('for', 'open'), 'in'): 1,
#              (('open', 'in'), 'same'): 2,
#              (('in', 'same'), 'window'): 2,
#              (('same', 'window'), 'formatparagraph'): 1,
#              (('window', 'formatparagraph'), 'py'): 1,
#              (('formatparagraph', 'py'), 'bindings'): 1,
#              (('bindings', 'tweaked'), 'idle'): 1,
#              (('tweaked', 'idle'), 'bat'): 1,
#              (('idle', 'bat'), 'removed'): 1,
#              (('bat', 'removed'), 'absolute'): 1,
#              (('removed', 'absolute'), 'pathname'): 1,
#              (('absolute', 'pathname'), 'idle'): 1,
#              (('pathname', 'idle'), 'pyw'): 1,
#              (('idle', 'pyw'), 'weird'): 1,
#              (('pyw', 'weird'), 'bug'): 1,
#              (('weird', 'bug'), 'due'): 1,
#              (('bug', 'due'), 'to'): 1,
#              (('due', 'to'), 'import'): 1,
#              (('to', 'import'), 'with'): 1,
#              (('import', 'with'), 'same'): 1,
#              (('with', 'same'), 'name'): 1,
#              (('same', 'name'), 'iobinding'): 1,
#              (('name', 'iobinding'), 'py'): 1,
#              (('iobinding', 'py'), 'open'): 1,
#              (('py', 'open'), 'in'): 1,
#              (('same', 'window'), 'eol'): 1,
#              (('window', 'eol'), 'convention'): 1,
#              (('eol', 'convention'), 'keydefs'): 1,
#              (('convention', 'keydefs'), 'py'): 1,
#              (('keydefs', 'py'), 'bindings'): 1,
#              (('bindings', 'tweaked'), 'outputwindow'): 1,
#              (('tweaked', 'outputwindow'), 'py'): 1,
#              (('outputwindow', 'py'), 'readline'): 1,
#              (('py', 'readline'), 'scroll_clear'): 1,
#              (('readline', 'scroll_clear'), 'etc'): 1,
#              (('scroll_clear', 'etc'), 'pyshell'): 1,
#              (('etc', 'pyshell'), 'py'): 1,
#              (('pyshell', 'py'), 'changed'): 1,
#              (('py', 'changed'), 'startup'): 1,
#              (('changed', 'startup'), 'behavior'): 1,
#              (('startup', 'behavior'), 'readme'): 1,
#              (('behavior', 'readme'), 'txt'): 1,
#              (('readme', 'txt'), 'recursion'): 1,
#              (('txt', 'recursion'), 'on'): 1,
#              (('recursion', 'on'), 'file'): 1,
#              (('on', 'file'), 'with'): 1,
#              (('file', 'with'), 'id'): 1,
#              (('with', 'id'), '1234567'): 1,
#              (('id', '1234567'), 'idle'): 1,
#              (('1234567', 'idle'), '0'): 1,
#              (('0', '5'), 'february'): 1,
#              (('5', 'february'), '2000'): 1,
#              (('february', '2000'), 'release'): 1,
#              (('2000', 'release'), 'notes'): 1,
#              (('release', 'notes'), 'this'): 1,
#              (('notes', 'this'), 'is'): 1,
#              (('this', 'is'), 'an'): 1,
#              (('is', 'an'), 'early'): 1,
#              (('an', 'early'), 'release'): 1,
#              (('early', 'release'), 'of'): 1,
#              (('of', 'idle'), 'my'): 1,
#              (('idle', 'my'), 'own'): 1,
#              (('my', 'own'), 'attempt'): 1,
#              (('own', 'attempt'), 'at'): 1,
#              (('attempt', 'at'), 'a'): 1,
#              (('at', 'a'), 'tkinter'): 1,
#              (('a', 'tkinter'), 'based'): 1,
#              (('tkinter', 'based'), 'ide'): 1,
#              (('based', 'ide'), 'for'): 1,
#              (('ide', 'for'), 'python'): 1,
#              (('for', 'python'), 'for'): 1,
#              (('python', 'for'), 'a'): 1,
#              (('for', 'a'), 'more'): 1,
#              (('a', 'more'), 'detailed'): 1,
#              (('more', 'detailed'), 'change'): 1,
#              (('detailed', 'change'), 'log'): 1,
#              (('change', 'log'), 'see'): 1,
#              (('log', 'see'), 'the'): 1,
#              (('see', 'the'), 'file'): 1,
#              (('the', 'file'), 'changelog'): 1,
#              (('file', 'changelog'), 'features'): 1,
#              (('changelog', 'features'), 'idle'): 1,
#              (('features', 'idle'), 'has'): 1,
#              (('idle', 'has'), 'the'): 1,
#              (('has', 'the'), 'following'): 1,
#              (('the', 'following'), 'features'): 1,
#              (('following', 'features'), 'coded'): 1,
#              (('features', 'coded'), 'in'): 1,
#              (('coded', 'in'), '100'): 1,
#              (('in', '100'), 'pure'): 1,
#              (('100', 'pure'), 'python'): 1,
#              (('pure', 'python'), 'using'): 1,
#              (('python', 'using'), 'the'): 1,
#              (('using', 'the'), 'tkinter'): 1,
#              (('the', 'tkinter'), 'gui'): 1,
#              (('tkinter', 'gui'), 'toolkit'): 1,
#              (('gui', 'toolkit'), 'i'): 1,
#              (('toolkit', 'i'), 'e'): 1,
#              (('i', 'e'), 'tcl'): 1,
#              (('e', 'tcl'), 'tk'): 1,
#              (('tcl', 'tk'), 'cross'): 1,
#              (('tk', 'cross'), 'platform'): 1,
#              (('cross', 'platform'), 'works'): 1,
#              (('platform', 'works'), 'on'): 1,
#              (('on', 'windows'), 'and'): 1,
#              (('windows', 'and'), 'unix'): 1,
#              (('and', 'unix'), 'on'): 1,
#              (('unix', 'on'), 'the'): 1,
#              (('on', 'the'), 'mac'): 1,
#              (('the', 'mac'), 'there'): 1,
#              (('mac', 'there'), 'are'): 1,
#              (('there', 'are'), 'currently'): 1,
#              (('are', 'currently'), 'problems'): 1,
#              (('currently', 'problems'), 'with'): 1,
#              (('problems', 'with'), 'tcl'): 1,
#              (('with', 'tcl'), 'tk'): 1,
#              (('tcl', 'tk'), 'multi'): 1,
#              (('tk', 'multi'), 'window'): 1,
#              (('multi', 'window'), 'text'): 1,
#              (('window', 'text'), 'editor'): 1,
#              (('text', 'editor'), 'with'): 1,
#              (('editor', 'with'), 'multiple'): 1,
#              (('with', 'multiple'), 'undo'): 1,
#              (('multiple', 'undo'), 'python'): 1,
#              (('undo', 'python'), 'colorizing'): 1,
#              (('python', 'colorizing'), 'and'): 1,
#              (('colorizing', 'and'), 'many'): 1,
#              (('and', 'many'), 'other'): 1,
#              (('many', 'other'), 'features'): 1,
#              (('other', 'features'), 'e'): 1,
#              (('features', 'e'), 'g'): 1,
#              (('e', 'g'), 'smart'): 1,
#              (('g', 'smart'), 'indent'): 1,
#              (('smart', 'indent'), 'and'): 1,
#              (('indent', 'and'), 'call'): 1,
#              (('and', 'call'), 'tips'): 1,
#              (('call', 'tips'), 'python'): 1,
#              (('tips', 'python'), 'shell'): 1,
#              (('python', 'shell'), 'window'): 3,
#              (('shell', 'window'), 'a'): 1,
#              (('window', 'a'), 'k'): 1,
#              (('a', 'k'), 'a'): 1,
#              (('k', 'a'), 'interactive'): 1,
#              (('a', 'interactive'), 'interpreter'): 1,
#              (('interactive', 'interpreter'), 'debugger'): 1,
#              (('interpreter', 'debugger'), 'not'): 1,
#              (('debugger', 'not'), 'complete'): 1,
#              (('not', 'complete'), 'but'): 1,
#              (('complete', 'but'), 'you'): 1,
#              (('but', 'you'), 'can'): 1,
#              (('you', 'can'), 'set'): 1,
#              (('can', 'set'), 'breakpoints'): 1,
#              (('set', 'breakpoints'), 'view'): 1,
#              (('breakpoints', 'view'), 'and'): 1,
#              (('view', 'and'), 'step'): 1,
#              (('and', 'step'), 'usage'): 1,
#              (('step', 'usage'), 'the'): 1,
#              (('usage', 'the'), 'main'): 1,
#              (('the', 'main'), 'program'): 1,
#              (('main', 'program'), 'is'): 1,
#              (('program', 'is'), 'in'): 1,
#              (('is', 'in'), 'the'): 1,
#              (('in', 'the'), 'file'): 2,
#              (('the', 'file'), 'idle'): 1,
#              (('file', 'idle'), 'py'): 1,
#              (('idle', 'py'), 'on'): 1,
#              (('py', 'on'), 'unix'): 1,
#              (('on', 'unix'), 'you'): 1,
#              (('unix', 'you'), 'should'): 1,
#              (('you', 'should'), 'be'): 1,
#              (('should', 'be'), 'able'): 1,
#              (('be', 'able'), 'to'): 1,
#              (('able', 'to'), 'run'): 1,
#              (('to', 'run'), 'it'): 1,
#              (('run', 'it'), 'by'): 2,
#              (('it', 'by'), 'typing'): 1,
#              (('by', 'typing'), 'idle'): 1,
#              (('typing', 'idle'), 'py'): 1,
#              (('idle', 'py'), 'to'): 1,
#              (('py', 'to'), 'your'): 1,
#              (('to', 'your'), 'shell'): 1,
#              (('your', 'shell'), 'on'): 1,
#              (('shell', 'on'), 'windows'): 1,
#              (('on', 'windows'), 'you'): 1,
#              (('windows', 'you'), 'can'): 1,
#              (('you', 'can'), 'run'): 1,
#              (('can', 'run'), 'it'): 1,
#              (('it', 'by'), 'double'): 1,
#              (('by', 'double'), 'clicking'): 1,
#              (('double', 'clicking'), 'it'): 1,
#              (('clicking', 'it'), 'you'): 1,
#              (('it', 'you'), 'can'): 1,
#              (('you', 'can'), 'use'): 1,
#              (('can', 'use'), 'idle'): 1,
#              (('use', 'idle'), 'pyw'): 1,
#              (('idle', 'pyw'), 'to'): 1,
#              (('pyw', 'to'), 'avoid'): 1,
#              (('to', 'avoid'), 'popping'): 1,
#              (('avoid', 'popping'), 'up'): 1,
#              (('popping', 'up'), 'a'): 1,
#              (('up', 'a'), 'dos'): 1,
#              (('a', 'dos'), 'console'): 1,
#              (('dos', 'console'), 'if'): 1,
#              (('console', 'if'), 'you'): 1,
#              (('if', 'you'), 'want'): 1,
#              (('you', 'want'), 'to'): 1,
#              (('want', 'to'), 'pass'): 1,
#              (('to', 'pass'), 'command'): 1,
#              (('pass', 'command'), 'line'): 1,
#              (('line', 'arguments'), 'on'): 1,
#              (('arguments', 'on'), 'windows'): 1,
#              (('on', 'windows'), 'use'): 1,
#              (('windows', 'use'), 'the'): 1,
#              (('use', 'the'), 'batch'): 1,
#              (('the', 'batch'), 'file'): 1,
#              (('batch', 'file'), 'idle'): 1,
#              (('file', 'idle'), 'bat'): 1,
#              (('idle', 'bat'), 'command'): 1,
#              (('bat', 'command'), 'line'): 1,
#              (('line', 'arguments'), 'files'): 1,
#              (('arguments', 'files'), 'passed'): 1,
#              (('files', 'passed'), 'on'): 1,
#              (('passed', 'on'), 'the'): 1,
#              (('on', 'the'), 'command'): 1,
#              (('the', 'command'), 'line'): 1,
#              (('command', 'line'), 'are'): 1,
#              (('line', 'are'), 'executed'): 1,
#              (('are', 'executed'), 'not'): 1,
#              (('executed', 'not'), 'opened'): 1,
#              (('not', 'opened'), 'for'): 1,
#              (('opened', 'for'), 'editing'): 1,
#              (('for', 'editing'), 'unless'): 1,
#              (('editing', 'unless'), 'you'): 1,
#              (('unless', 'you'), 'give'): 1,
#              (('you', 'give'), 'the'): 1,
#              (('give', 'the'), 'e'): 1,
#              (('the', 'e'), 'command'): 1,
#              (('e', 'command'), 'line'): 1,
#              (('command', 'line'), 'option'): 1,
#              (('line', 'option'), 'try'): 1,
#              (('option', 'try'), 'idle'): 1,
#              (('try', 'idle'), 'py'): 1,
#              (('idle', 'py'), 'h'): 1,
#              (('py', 'h'), 'to'): 1,
#              (('h', 'to'), 'see'): 1,
#              (('to', 'see'), 'other'): 1,
#              (('see', 'other'), 'command'): 1,
#              (('other', 'command'), 'line'): 1,
#              (('command', 'line'), 'options'): 1,
#              (('line', 'options'), 'idle'): 1,
#              (('options', 'idle'), 'requires'): 1,
#              (('idle', 'requires'), 'python'): 1,
#              (('requires', 'python'), '1'): 1,
#              (('python', '1'), '5'): 5,
#              (('1', '5'), '2'): 3,
#              (('5', '2'), 'so'): 1,
#              (('2', 'so'), 'it'): 1,
#              (('so', 'it'), 'is'): 1,
#              (('it', 'is'), 'currently'): 1,
#              (('is', 'currently'), 'only'): 1,
#              (('currently', 'only'), 'usable'): 1,
#              (('only', 'usable'), 'with'): 1,
#              (('usable', 'with'), 'a'): 1,
#              (('with', 'a'), 'python'): 1,
#              (('a', 'python'), '1'): 1,
#              (('5', '2'), 'distribution'): 1,
#              (('2', 'distribution'), 'an'): 1,
#              (('distribution', 'an'), 'older'): 1,
#              (('an', 'older'), 'version'): 1,
#              (('older', 'version'), 'of'): 1,
#              (('of', 'idle'), 'is'): 1,
#              (('idle', 'is'), 'distributed'): 1,
#              (('is', 'distributed'), 'with'): 1,
#              (('distributed', 'with'), 'python'): 1,
#              (('with', 'python'), '1'): 1,
#              (('5', '2'), 'you'): 1,
#              (('2', 'you'), 'can'): 1,
#              (('you', 'can'), 'drop'): 1,
#              (('can', 'drop'), 'this'): 1,
#              (('drop', 'this'), 'version'): 1,
#              (('this', 'version'), 'on'): 1,
#              (('version', 'on'), 'top'): 1,
#              (('on', 'top'), 'of'): 1,
#              (('top', 'of'), 'it'): 1,
#              (('of', 'it'), 'copyright'): 1,
#              (('it', 'copyright'), 'idle'): 1,
#              (('copyright', 'idle'), 'is'): 1,
#              (('idle', 'is'), 'covered'): 1,
#              (('is', 'covered'), 'by'): 1,
#              (('covered', 'by'), 'the'): 1,
#              (('by', 'the'), 'standard'): 1,
#              (('the', 'standard'), 'python'): 1,
#              (('standard', 'python'), 'copyright'): 1,
#              (('python', 'copyright'), 'notice'): 1,
#              (('copyright', 'notice'), 'http'): 1,
#              (('notice', 'http'), 'www'): 1,
#              (('python', 'org'), 'doc'): 1,
#              (('org', 'doc'), 'copyright'): 1,
#              (('doc', 'copyright'), 'html'): 1,
#              (('copyright', 'html'), 'new'): 1,
#              (('html', 'new'), 'in'): 1,
#              (('new', 'in'), 'idle'): 4,
#              (('in', 'idle'), '0'): 4,
#              (('0', '5'), '2'): 1,
#              (('5', '2'), '15'): 1,
#              (('2', '15'), '2000'): 1,
#              (('15', '2000'), 'tons'): 1,
#              (('2000', 'tons'), 'of'): 1,
#              (('tons', 'of'), 'stuff'): 1,
#              (('of', 'stuff'), 'much'): 1,
#              (('stuff', 'much'), 'of'): 1,
#              (('much', 'of'), 'it'): 1,
#              (('of', 'it'), 'contributed'): 1,
#              (('it', 'contributed'), 'by'): 1,
#              (('contributed', 'by'), 'tim'): 1,
#              (('by', 'tim'), 'peters'): 1,
#              (('tim', 'peters'), 'and'): 1,
#              (('peters', 'and'), 'mark'): 1,
#              (('and', 'mark'), 'hammond'): 1,
#              (('mark', 'hammond'), 'status'): 1,
#              (('hammond', 'status'), 'bar'): 1,
#              (('status', 'bar'), 'displaying'): 1,
#              (('bar', 'displaying'), 'current'): 1,
#              (('displaying', 'current'), 'line'): 1,
#              (('current', 'line'), 'column'): 1,
#              (('line', 'column'), 'moshe'): 1,
#              (('column', 'moshe'), 'zadka'): 1,
#              (('moshe', 'zadka'), 'better'): 1,
#              (('zadka', 'better'), 'stack'): 1,
#              (('better', 'stack'), 'viewer'): 1,
#              (('stack', 'viewer'), 'using'): 1,
#              (('viewer', 'using'), 'tree'): 1,
#              (('using', 'tree'), 'widget'): 1,
#              (('tree', 'widget'), 'xxx'): 1,
#              (('widget', 'xxx'), 'only'): 1,
#              (('xxx', 'only'), 'used'): 1,
#              (('only', 'used'), 'by'): 1,
#              (('used', 'by'), 'stack'): 1,
#              (('by', 'stack'), 'viewer'): 1,
#              (('stack', 'viewer'), 'menu'): 2,
#              (('viewer', 'menu'), 'not'): 1,
#              (('menu', 'not'), 'by'): 1,
#              ...})

# %%
import random
from collections import defaultdict, Counter
import string

def preprocess_text(text):
    """Removes punctuation from the text."""
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

def build_transition_matrix(corpus, order=1):
    """Builds a transition matrix with frequency of occurrence."""
    transition_matrix = defaultdict(Counter)
    words = corpus.split()
    for i in range(len(words) - order):
        current_sequence = tuple(words[i:i+order])
        next_word = words[i + order]
        transition_matrix[current_sequence][next_word] += 1
    print(transition_matrix)
    return transition_matrix

def generate_text1(transition_matrix, start_sequence, output_length):
    """Generates text using the transition matrix."""
    current_sequence = start_sequence
    generated_text = list(current_sequence)

    for _ in range(output_length - len(start_sequence)):
        next_word_counter = transition_matrix[current_sequence]
        if next_word_counter:
            total_occurrences = sum(next_word_counter.values())
            probabilities = [count / total_occurrences for count in next_word_counter.values()]
            next_word = random.choices(list(next_word_counter.keys()), weights=probabilities)[0]
        else:
            # If transition matrix is empty, choose a random word from the entire vocabulary
            next_word = random.choice(list(transition_matrix.keys())[0])

        generated_text.append(next_word)
        current_sequence = tuple(generated_text[-len(start_sequence):])

    return ' '.join(generated_text)


# Example usage:
corpus = "The cat sat on the mat, the dog barked!"
corpus = preprocess_text(corpus)
transition_matrix = build_transition_matrix(corpus, order=2)
output_text = generate_text1(transition_matrix, ('The', 'cat'), 10)
print(output_text)
# Out:
# defaultdict(<class 'collections.Counter'>, {('The', 'cat'): Counter({'sat': 1}), ('cat', 'sat'): Counter({'on': 1}), ('sat', 'on'): Counter({'the': 1}), ('on', 'the'): Counter({'mat': 1}), ('the', 'mat'): Counter({'the': 1}), ('mat', 'the'): Counter({'dog': 1}), ('the', 'dog'): Counter({'barked': 1})})
# [ ' T h e ' ,   ' c a t ' ,   ' s a t ' ,   ' o n ' ,   ' t h e ' ,   ' m a t ' ,   ' t h e ' ,   ' d o g ' ,   ' b a r k e d ' ,   ' c a t ' ]

# %%
import random
from collections import defaultdict, Counter
import string

def preprocess_text(text):
    """Removes punctuation from the text."""
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

def build_transition_matrix(corpus, order=1):
    """Builds a transition matrix with frequency of occurrence."""
    transition_matrix = defaultdict(Counter)
    words = corpus.split()
    for i in range(len(words) - order):
        current_sequence = tuple(words[i:i+order])
        next_word = words[i + order]
        transition_matrix[current_sequence][next_word] += 1
    print(transition_matrix)
    return transition_matrix

def generate_text(transition_matrix, start_sequence, output_length):
    """Generates text using the transition matrix."""
    current_sequence = start_sequence
    generated_text = list(current_sequence)

    for _ in range(output_length - len(start_sequence)):
        next_word_counter = transition_matrix[current_sequence]
        if next_word_counter:
            total_occurrences = sum(next_word_counter.values())
            probabilities = [count / total_occurrences for count in next_word_counter.values()]
            next_word = random.choices(list(next_word_counter.keys()), weights=probabilities)[0]
        else:
            # If transition matrix is empty, choose a random word from the entire vocabulary
            next_word = random.choice(list(transition_matrix.keys())[0])

        generated_text.append(next_word)
        current_sequence = tuple(generated_text[-len(start_sequence):])

    print(generated_text)
    return ' '.join(generated_text)


corpus = "The cat sat on the mat, the dog barked!"
corpus = preprocess_text(corpus)
transition_matrix = build_transition_matrix(corpus, order=2)
output_text = generate_text(transition_matrix, ('The', 'cat'), 10)
print(output_text)
# Out:
# defaultdict(<class 'collections.Counter'>, {('The', 'cat'): Counter({'sat': 1}), ('cat', 'sat'): Counter({'on': 1}), ('sat', 'on'): Counter({'the': 1}), ('on', 'the'): Counter({'mat': 1}), ('the', 'mat'): Counter({'the': 1}), ('mat', 'the'): Counter({'dog': 1}), ('the', 'dog'): Counter({'barked': 1})})
# ['The', 'cat', 'sat', 'on', 'the', 'mat', 'the', 'dog', 'barked', 'The']
# The cat sat on the mat the dog barked The

# %%
# Test case 1: Basic test with a small corpus
corpus1 = "The cat sat on the mat, the dog barked!"
corpus1 = preprocess_text(corpus1)
transition_matrix1 = build_transition_matrix(corpus1, order=2)
output_text1 = generate_text(transition_matrix1, ('The', 'cat'), 10)
print("Test case 1 output:", output_text1)
# Out:
# defaultdict(<class 'collections.Counter'>, {('The', 'cat'): Counter({'sat': 1}), ('cat', 'sat'): Counter({'on': 1}), ('sat', 'on'): Counter({'the': 1}), ('on', 'the'): Counter({'mat': 1}), ('the', 'mat'): Counter({'the': 1}), ('mat', 'the'): Counter({'dog': 1}), ('the', 'dog'): Counter({'barked': 1})})
# ['The', 'cat', 'sat', 'on', 'the', 'mat', 'the', 'dog', 'barked', 'cat']
# Test case 1 output: The cat sat on the mat the dog barked cat

# %%
# Test case 2: Test with a larger corpus and higher order transitions
corpus2 = "I am Groot. I am Groot. I am Groot."
corpus2 = preprocess_text(corpus2)
transition_matrix2 = build_transition_matrix(corpus2, order=2)
output_text2 = generate_text(transition_matrix2, ('I', 'am'), 10)
print("Test case 2 output:", output_text2)
# Out:
# defaultdict(<class 'collections.Counter'>, {('I', 'am'): Counter({'Groot': 3}), ('am', 'Groot'): Counter({'I': 2}), ('Groot', 'I'): Counter({'am': 2})})
# ['I', 'am', 'Groot', 'I', 'am', 'Groot', 'I', 'am', 'Groot', 'I']
# Test case 2 output: I am Groot I am Groot I am Groot I

# %%
# Test case 3: Test with a corpus containing special characters
corpus3 = "Hello, world! This is a test string.Hello, world! This is a test string.Hello,Hello, world! This is a test string. world! This is a test string.Hello, world! This is a test string.Hello, world! This is a test string."
corpus3 = preprocess_text(corpus3)
transition_matrix3 = build_transition_matrix(corpus3, order=1)
output_text3 = generate_text(transition_matrix3, ('Hello',), 10)
print("Test case 3 output:", output_text3)
# Out:
# defaultdict(<class 'collections.Counter'>, {('Hello',): Counter({'world': 1}), ('world',): Counter({'This': 6}), ('This',): Counter({'is': 6}), ('is',): Counter({'a': 6}), ('a',): Counter({'test': 6}), ('test',): Counter({'stringHello': 3, 'string': 2, 'stringHelloHello': 1}), ('stringHello',): Counter({'world': 3}), ('stringHelloHello',): Counter({'world': 1}), ('string',): Counter({'world': 1})})
# ['Hello', 'world', 'This', 'is', 'a', 'test', 'string', 'world', 'This', 'is']
# Test case 3 output: Hello world This is a test string world This is
